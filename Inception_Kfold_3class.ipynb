# %% [markdown]
# <a href="https://colab.research.google.com/github/MMoltira/Chest-X-Ray-classification/blob/main/Inception_Kfold_3class.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ###### import

# %%
import os
import tensorflow as tf
import matplotlib.pyplot as plt
# %matplotlib inline
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint
import cv2
import numpy as np
import pandas as pd
from torchsummary import summary
from skimage.io import imread, imsave
from tqdm import tqdm

from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, confusion_matrix

# %%
# set the matplotlib backend so figures can be saved in the background
import matplotlib
matplotlib.use("Agg")

from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import classification_report
from tensorflow.keras.optimizers import SGD, Adam, RMSprop
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import load_model
from imutils import paths
import argparse

from sklearn.model_selection import KFold
from sklearn import metrics
from scipy.stats import zscore


import matplotlib.image as mpimg
from matplotlib.pyplot import savefig

import itertools
from sklearn.metrics import confusion_matrix
from sklearn.utils.multiclass import unique_labels

# %%
import pickle
import joblib

# %% [markdown]
# ######Load data // KKUmail

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
data_dir = '/content/drive/My Drive/Senior Project/CXR Image3class/Image'

# %% [markdown]
# train 3 class

# %%
Normal151_dir = os.path.join(data_dir,'Normal151')
TB150_dir = os.path.join(data_dir,'TB150')
CA150_dir = os.path.join(data_dir,'CA150')

All_3class_dir = os.path.join(data_dir,'All_3class')

# %% [markdown]
# ######Load data // Gmail

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
data_dir = '/content/drive/My Drive/Senior Project/CXR Image3class/Image'

# %% [markdown]
# train 3 class

# %%
Normal151_dir = os.path.join(data_dir,'Normal151')
TB150_dir = os.path.join(data_dir,'TB150')
CA150_dir = os.path.join(data_dir,'CA150')

All_3class_dir = os.path.join(data_dir,'All_3class')

# %% [markdown]
# #### train 3 class
# ข้อมูลใน All_3class_dir รวมภาพทั้ง 3 คลาส รวม 450 ภาพ TB150, Normal151 (เอามาแค่150) และ CA150 (CA คือ lungcancer)

# %%
Normal151_dir = os.path.join(data_dir,'Normal151')
TB150_dir = os.path.join(data_dir,'TB150')
CA150_dir = os.path.join(data_dir,'CA150')

All_3class_dir = os.path.join(data_dir,'All_3class')

# %%
normal = []
for i in range(len(os.listdir(Normal151_dir))):
    img = os.listdir(Normal151_dir)[i]
    normal.append(img)
    
tnormal = pd.DataFrame({'ImageName':[normal][0],
                                       'NameType': "Normal" ,
                                       'NumberType': 0                      })

# %%
tuberculosis = []
for i in range(len(os.listdir(TB150_dir))):
    img = os.listdir(TB150_dir)[i]
    tuberculosis.append(img)

ttuberculosis = pd.DataFrame({'ImageName':[tuberculosis][0],
                                       'NameType': "Tuberculosis" ,
                                       'NumberType': 1                        })

# %%
lungcancer = []
for i in range(len(os.listdir(CA150_dir))):
    img = os.listdir(CA150_dir)[i]
    lungcancer.append(img)

tlungcancer = pd.DataFrame({'ImageName':[lungcancer][0],
                                       'NameType': "Lungcancer" ,
                                       'NumberType': 2                        })

# %%
data_train3 = pd.concat([tnormal[:-1], ttuberculosis, tlungcancer])
data_train3[-3:]
# Out:
#      ImageName    NameType  NumberType
# 147   ca96.jpg  Lungcancer           2
# 148  ca108.jpg  Lungcancer           2
# 149   ca74.jpg  Lungcancer           2

# %% [markdown]
# # K-fold 0-100
# แก้เป็น k-fold หมดแล้ว
# เหลือลองรันว่าจะเจ้งมั้ย
# - 311 layer
# -   filepath มี .h5 ทุกอัน

# %% [markdown]
# ### 8

# %% [markdown]
# #### 8  soft pre bi

# %%
BS = 8
filepath = "Kmodel8_soft_pre_bi.h5"                  ##

train_img_Incep = []
for ImageName in tqdm(data_train3['ImageName']):              
    image_path = All_3class_dir +'/' + ImageName                  
    img = cv2.imread(image_path)                                          
    img = cv2.resize(img, (299, 299))                                      
    train_img_Incep.append(img)
data_Incep = np.array(train_img_Incep, dtype="float32") / 255.0

labels_Incep = np.array(data_train3[['NameType']] )        
labels_Incep.shape = (len(labels_Incep),) 
le_Incep = LabelEncoder()                                                                     
labels_Incep = le_Incep.fit_transform(labels_Incep)                                         
labels_Incep = to_categorical(labels_Incep, num_classes=3)                   

aug = ImageDataGenerator( rotation_range=15,	width_shift_range=0.1, 	height_shift_range=0.1,
		shear_range=0.15, 	horizontal_flip=True, 	fill_mode="nearest")
                                                                                                           ## 
callback = EarlyStopping( monitor= "val_accuracy",    patience=15,       mode="max" , baseline=1.0)

# checkpoint = ModelCheckpoint(filepath, monitor='val_accuracy', verbose=1,   save_best_only=True, mode='max')
                                                                                                            ##
reduce_lr = ReduceLROnPlateau(monitor='val_accuracy', factor=0.5,   patience=6,     verbose=1, mode='max', min_lr=0.00001)
# Out:
# 100%|██████████| 450/450 [00:08<00:00, 54.11it/s]

# %%
base_model_Incep = tf.keras.applications.InceptionV3(input_shape=(299, 299, 3), include_top=False, weights="imagenet")
len(base_model_Incep.layers)

base_model_Incep.trainable = True
for layer in base_model_Incep.layers[:100]:    #fix w & bias in layer 0-100
    layer.trainable = False


#Add custom head
average_pooling_layer = tf.keras.layers.GlobalAveragePooling2D()(base_model_Incep.output)
prediction_layer = tf.keras.layers.Dense(units=3, activation="softmax")(average_pooling_layer)   # unit 3
model_Incep = tf.keras.models.Model(inputs=base_model_Incep.input, outputs=prediction_layer)

model_Incep.compile(optimizer=RMSprop(learning_rate=0.0001), loss="binary_crossentropy", metrics=["accuracy"])


### K-fold
kf_Incep = KFold(5, shuffle=True, random_state=40) 

oos_y = []
oos_pred = []
fold = 0

for train, test in kf_Incep.split(data_Incep):
    fold+=1   
    print(f"Fold #{fold}")

    filename = f" Kmodel8_soft_pre_bi{fold}.h5 "
    checkpoint = ModelCheckpoint(filename, monitor='val_accuracy', verbose=1,   save_best_only=True, mode='max')
        
    x_train_Incep = data_Incep[train]
    y_train_Incep = labels_Incep[train]
    x_test_Incep = data_Incep[test]
    y_test_Incep = labels_Incep[test]

    H_Incep = model_Incep.fit( x=aug.flow(x_train_Incep, y_train_Incep, batch_size=BS),
	                                            validation_data=(x_test_Incep, y_test_Incep),
	                                            steps_per_epoch=len(x_train_Incep) // BS,
	                                            epochs=100,  callbacks = [callback,checkpoint,reduce_lr])

    pred_Incep = model_Incep.predict(x_test_Incep)
    
    oos_y.append(y_test_Incep)
    oos_pred.append(pred_Incep)  
    print(classification_report(y_test_Incep.argmax(axis=1),	                #แสดง report ค่า acc, recall, ...
                                        pred_Incep.argmax(axis=1),  
                                        target_names=le_Incep.classes_))
    
oos_y = np.concatenate(oos_y)
oos_pred = np.concatenate(oos_pred)
print(classification_report(oos_y.argmax(axis=1), oos_pred.argmax(axis=1),  target_names=le_Incep.classes_))
# Out:
# Fold #1
# Epoch 1/100
# 45/45 [==============================] - ETA: 0s - loss: 0.4840 - accuracy: 0.6028
# Epoch 1: val_accuracy improved from -inf to 0.46667, saving model to  Kmodel8_soft_pre_bi1.h5
# INFO:tensorflow:Assets written to:  Kmodel8_soft_pre_bi1.h5 /assets
# 45/45 [==============================] - 79s 1s/step - loss: 0.4840 - accuracy: 0.6028 - val_loss: 0.6641 - val_accuracy: 0.4667 - lr: 1.0000e-04
# Epoch 2/100
# 45/45 [==============================] - ETA: 0s - loss: 0.3322 - accuracy: 0.7833
# Epoch 2: val_accuracy improved from 0.46667 to 0.65556, saving model to  Kmodel8_soft_pre_bi1.h5
# INFO:tensorflow:Assets written to:  Kmodel8_soft_pre_bi1.h5 /assets
# 45/45 [==============================] - 47s 1s/step - loss: 0.3322 - accuracy: 0.7833 - val_loss: 0.4713 - val_accuracy: 0.6556 - lr: 1.0000e-04
# Epoch 3/100
# 45/45 [==============================] - ETA: 0s - loss: 0.2891 - accuracy: 0.8194
# Epoch 3: val_accuracy improved from 0.65556 to 0.67778, saving model to  Kmodel8_soft_pre_bi1.h5
# INFO:tensorflow:Assets written to:  Kmodel8_soft_pre_bi1.h5 /assets
# 45/45 [==============================] - 48s 1s/step - loss: 0.2891 - accuracy: 0.8194 - val_loss: 0.6925 - val_accuracy: 0.6778 - lr: 1.0000e-04
# Epoch 4/100
# 45/45 [==============================] - ETA: 0s - loss: 0.2335 - accuracy: 0.8694
# Epoch 4: val_accuracy did not improve from 0.67778
# 45/45 [==============================] - 12s 257ms/step - loss: 0.2335 - accuracy: 0.8694 - val_loss: 0.8138 - val_accuracy: 0.6778 - lr: 1.0000e-04
# Epoch 5/100
# 45/45 [==============================] - ETA: 0s - loss: 0.1847 - accuracy: 0.8972
# Epoch 5: val_accuracy improved from 0.67778 to 0.71111, saving model to  Kmodel8_soft_pre_bi1.h5
# INFO:tensorflow:Assets written to:  Kmodel8_soft_pre_bi1.h5 /assets
# 45/45 [==============================] - 48s 1s/step - loss: 0.1847 - accuracy: 0.8972 - val_loss: 0.7355 - val_accuracy: 0.7111 - lr: 1.0000e-04
# Epoch 6/100
# 45/45 [==============================] - ETA: 0s - loss: 0.1795 - accuracy: 0.8861
# Epoch 6: val_accuracy improved from 0.71111 to 0.74444, saving model to  Kmodel8_soft_pre_bi1.h5
# INFO:tensorflow:Assets written to:  Kmodel8_soft_pre_bi1.h5 /assets
# 45/45 [==============================] - 48s 1s/step - loss: 0.1795 - accuracy: 0.8861 - val_loss: 0.5489 - val_accuracy: 0.7444 - lr: 1.0000e-04
# Epoch 7/100
# 45/45 [==============================] - ETA: 0s - loss: 0.1650 - accuracy: 0.9278
# Epoch 7: val_accuracy improved from 0.74444 to 0.91111, saving model to  Kmodel8_soft_pre_bi1.h5
# INFO:tensorflow:Assets written to:  Kmodel8_soft_pre_bi1.h5 /assets
# 45/45 [==============================] - 48s 1s/step - loss: 0.1650 - accuracy: 0.9278 - val_loss: 0.2309 - val_accuracy: 0.9111 - lr: 1.0000e-04
# Epoch 8/100
# 45/45 [==============================] - ETA: 0s - loss: 0.1892 - accuracy: 0.8722
# Epoch 8: val_accuracy did not improve from 0.91111
# 45/45 [==============================] - 12s 255ms/step - loss: 0.1892 - accuracy: 0.8722 - val_loss: 0.4111 - val_accuracy: 0.8000 - lr: 1.0000e-04
# Epoch 9/100
# 45/45 [==============================] - ETA: 0s - loss: 0.1378 - accuracy: 0.9167
# Epoch 9: val_accuracy did not improve from 0.91111
# 45/45 [==============================] - 12s 253ms/step - loss: 0.1378 - accuracy: 0.9167 - val_loss: 0.5370 - val_accuracy: 0.8111 - lr: 1.0000e-04
# Epoch 10/100
# 45/45 [==============================] - ETA: 0s - loss: 0.1146 - accuracy: 0.9417
# Epoch 10: val_accuracy did not improve from 0.91111
# 45/45 [==============================] - 12s 258ms/step - loss: 0.1146 - accuracy: 0.9417 - val_loss: 0.5755 - val_accuracy: 0.7889 - lr: 1.0000e-04
# Epoch 11/100
# 45/45 [==============================] - ETA: 0s - loss: 0.1065 - accuracy: 0.9333
# Epoch 11: val_accuracy did not improve from 0.91111
# 45/45 [==============================] - 12s 258ms/step - loss: 0.1065 - accuracy: 0.9333 - val_loss: 0.3862 - val_accuracy: 0.8333 - lr: 1.0000e-04
# Epoch 12/100
# 45/45 [==============================] - ETA: 0s - loss: 0.0926 - accuracy: 0.9556
# Epoch 12: val_accuracy improved from 0.91111 to 0.92222, saving model to  Kmodel8_soft_pre_bi1.h5
# INFO:tensorflow:Assets written to:  Kmodel8_soft_pre_bi1.h5 /assets
# 45/45 [==============================] - 48s 1s/step - loss: 0.0926 - accuracy: 0.9556 - val_loss: 0.2179 - val_accuracy: 0.9222 - lr: 1.0000e-04
# Epoch 13/100
# 45/45 [==============================] - ETA: 0s - loss: 0.1058 - accuracy: 0.9583
# Epoch 13: val_accuracy did not improve from 0.92222
# 45/45 [==============================] - 12s 260ms/step - loss: 0.1058 - accuracy: 0.9583 - val_loss: 0.2293 - val_accuracy: 0.8667 - lr: 1.0000e-04
# Epoch 14/100
# 45/45 [==============================] - ETA: 0s - loss: 0.0851 - accuracy: 0.9639
# Epoch 14: val_accuracy did not improve from 0.92222
# 45/45 [==============================] - 12s 257ms/step - loss: 0.0851 - accuracy: 0.9639 - val_loss: 1.2277 - val_accuracy: 0.6667 - lr: 1.0000e-04
# Epoch 15/100
# 45/45 [==============================] - ETA: 0s - loss: 0.0770 - accuracy: 0.9667
# Epoch 15: val_accuracy did not improve from 0.92222
# 45/45 [==============================] - 12s 256ms/step - loss: 0.0770 - accuracy: 0.9667 - val_loss: 0.4817 - val_accuracy: 0.8333 - lr: 1.0000e-04
#               precision    recall  f1-score   support
#
#   Lungcancer       0.76      1.00      0.86        28
#       Normal       0.96      0.71      0.81        31
# Tuberculosis       0.83      0.81      0.82        31
#
#     accuracy                           0.83        90
#    macro avg       0.85      0.84      0.83        90
# weighted avg       0.85      0.83      0.83        90
#
# Fold #2
# Epoch 1/100
# 45/45 [==============================] - ETA: 0s - loss: 0.1523 - accuracy: 0.9111
# Epoch 1: val_accuracy improved from -inf to 1.00000, saving model to  Kmodel8_soft_pre_bi2.h5
# INFO:tensorflow:Assets written to:  Kmodel8_soft_pre_bi2.h5 /assets
# 45/45 [==============================] - 49s 1s/step - loss: 0.1523 - accuracy: 0.9111 - val_loss: 0.0015 - val_accuracy: 1.0000 - lr: 1.0000e-04
# Epoch 2/100
# 45/45 [==============================] - ETA: 0s - loss: 0.1270 - accuracy: 0.9389
# Epoch 2: val_accuracy did not improve from 1.00000
# 45/45 [==============================] - 12s 257ms/step - loss: 0.1270 - accuracy: 0.9389 - val_loss: 0.0138 - val_accuracy: 0.9889 - lr: 1.0000e-04
# Epoch 3/100
# 45/45 [==============================] - ETA: 0s - loss: 0.1011 - accuracy: 0.9472
# Epoch 3: val_accuracy did not improve from 1.00000
# 45/45 [==============================] - 12s 256ms/step - loss: 0.1011 - accuracy: 0.9472 - val_loss: 0.0191 - val_accuracy: 0.9889 - lr: 1.0000e-04
# Epoch 4/100
# 45/45 [==============================] - ETA: 0s - loss: 0.0595 - accuracy: 0.9694
# Epoch 4: val_accuracy did not improve from 1.00000
# 45/45 [==============================] - 12s 255ms/step - loss: 0.0595 - accuracy: 0.9694 - val_loss: 2.8349 - val_accuracy: 0.4444 - lr: 1.0000e-04
# Epoch 5/100
# 45/45 [==============================] - ETA: 0s - loss: 0.0752 - accuracy: 0.9556
# Epoch 5: val_accuracy did not improve from 1.00000
# 45/45 [==============================] - 12s 257ms/step - loss: 0.0752 - accuracy: 0.9556 - val_loss: 1.5278 - val_accuracy: 0.6333 - lr: 1.0000e-04
# Epoch 6/100
# 45/45 [==============================] - ETA: 0s - loss: 0.0592 - accuracy: 0.9694
# Epoch 6: val_accuracy did not improve from 1.00000
# 45/45 [==============================] - 12s 261ms/step - loss: 0.0592 - accuracy: 0.9694 - val_loss: 0.4632 - val_accuracy: 0.7667 - lr: 1.0000e-04
# Epoch 7/100
# 45/45 [==============================] - ETA: 0s - loss: 0.0853 - accuracy: 0.9639
# Epoch 7: val_accuracy did not improve from 1.00000
#
# Epoch 7: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 45/45 [==============================] - 12s 256ms/step - loss: 0.0853 - accuracy: 0.9639 - val_loss: 0.4635 - val_accuracy: 0.8000 - lr: 1.0000e-04
# Epoch 8/100
# 45/45 [==============================] - ETA: 0s - loss: 0.0606 - accuracy: 0.9667
# Epoch 8: val_accuracy did not improve from 1.00000
# 45/45 [==============================] - 12s 258ms/step - loss: 0.0606 - accuracy: 0.9667 - val_loss: 0.4181 - val_accuracy: 0.7778 - lr: 5.0000e-05
# Epoch 9/100
# 45/45 [==============================] - ETA: 0s - loss: 0.0522 - accuracy: 0.9639
# Epoch 9: val_accuracy did not improve from 1.00000
# 45/45 [==============================] - 12s 257ms/step - loss: 0.0522 - accuracy: 0.9639 - val_loss: 0.5269 - val_accuracy: 0.7222 - lr: 5.0000e-05
# Epoch 10/100
# 45/45 [==============================] - ETA: 0s - loss: 0.0578 - accuracy: 0.9667
# Epoch 10: val_accuracy did not improve from 1.00000
# 45/45 [==============================] - 12s 255ms/step - loss: 0.0578 - accuracy: 0.9667 - val_loss: 0.2101 - val_accuracy: 0.8333 - lr: 5.0000e-05
# Epoch 11/100
# 45/45 [==============================] - ETA: 0s - loss: 0.0226 - accuracy: 0.9889
# Epoch 11: val_accuracy did not improve from 1.00000
# 45/45 [==============================] - 12s 256ms/step - loss: 0.0226 - accuracy: 0.9889 - val_loss: 0.6719 - val_accuracy: 0.7222 - lr: 5.0000e-05
# Epoch 12/100
# 45/45 [==============================] - ETA: 0s - loss: 0.0267 - accuracy: 0.9889
# Epoch 12: val_accuracy did not improve from 1.00000
# 45/45 [==============================] - 12s 259ms/step - loss: 0.0267 - accuracy: 0.9889 - val_loss: 0.6187 - val_accuracy: 0.6889 - lr: 5.0000e-05
# Epoch 13/100
# 45/45 [==============================] - ETA: 0s - loss: 0.0333 - accuracy: 0.9889
# Epoch 13: val_accuracy did not improve from 1.00000
#
# Epoch 13: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# 45/45 [==============================] - 12s 257ms/step - loss: 0.0333 - accuracy: 0.9889 - val_loss: 0.4011 - val_accuracy: 0.8000 - lr: 5.0000e-05
# Epoch 14/100
# 45/45 [==============================] - ETA: 0s - loss: 0.0196 - accuracy: 0.9944
# Epoch 14: val_accuracy did not improve from 1.00000
# 45/45 [==============================] - 12s 263ms/step - loss: 0.0196 - accuracy: 0.9944 - val_loss: 0.1996 - val_accuracy: 0.8556 - lr: 2.5000e-05
# Epoch 15/100
# 45/45 [==============================] - ETA: 0s - loss: 0.0289 - accuracy: 0.9917
# Epoch 15: val_accuracy did not improve from 1.00000
# 45/45 [==============================] - 12s 260ms/step - loss: 0.0289 - accuracy: 0.9917 - val_loss: 0.3370 - val_accuracy: 0.7889 - lr: 2.5000e-05
#               precision    recall  f1-score   support
#
#   Lungcancer       1.00      0.47      0.64        34
#       Normal       0.96      0.96      0.96        27
# Tuberculosis       0.62      1.00      0.76        29
#
#     accuracy                           0.79        90
#    macro avg       0.86      0.81      0.79        90
# weighted avg       0.87      0.79      0.78        90
#
# Fold #3
# Epoch 1/100
# 45/45 [==============================] - ETA: 0s - loss: 0.0377 - accuracy: 0.9833
# Epoch 1: val_accuracy improved from -inf to 0.95556, saving model to  Kmodel8_soft_pre_bi3.h5
# INFO:tensorflow:Assets written to:  Kmodel8_soft_pre_bi3.h5 /assets
# 45/45 [==============================] - 49s 1s/step - loss: 0.0377 - accuracy: 0.9833 - val_loss: 0.0700 - val_accuracy: 0.9556 - lr: 2.5000e-05
# Epoch 2/100
# 45/45 [==============================] - ETA: 0s - loss: 0.0264 - accuracy: 0.9833
# Epoch 2: val_accuracy did not improve from 0.95556
# 45/45 [==============================] - 12s 256ms/step - loss: 0.0264 - accuracy: 0.9833 - val_loss: 0.0625 - val_accuracy: 0.9556 - lr: 2.5000e-05
# Epoch 3/100
# 45/45 [==============================] - ETA: 0s - loss: 0.0362 - accuracy: 0.9833
# Epoch 3: val_accuracy did not improve from 0.95556
# 45/45 [==============================] - 12s 254ms/step - loss: 0.0362 - accuracy: 0.9833 - val_loss: 0.1043 - val_accuracy: 0.9556 - lr: 2.5000e-05
# Epoch 4/100
# 45/45 [==============================] - ETA: 0s - loss: 0.0157 - accuracy: 0.9944
# Epoch 4: val_accuracy did not improve from 0.95556
# 45/45 [==============================] - 12s 258ms/step - loss: 0.0157 - accuracy: 0.9944 - val_loss: 0.0890 - val_accuracy: 0.9556 - lr: 2.5000e-05
# Epoch 5/100
# 45/45 [==============================] - ETA: 0s - loss: 0.0184 - accuracy: 0.9944
# Epoch 5: val_accuracy improved from 0.95556 to 0.96667, saving model to  Kmodel8_soft_pre_bi3.h5
# INFO:tensorflow:Assets written to:  Kmodel8_soft_pre_bi3.h5 /assets
# 45/45 [==============================] - 51s 1s/step - loss: 0.0184 - accuracy: 0.9944 - val_loss: 0.0661 - val_accuracy: 0.9667 - lr: 2.5000e-05
# Epoch 6/100
# 45/45 [==============================] - ETA: 0s - loss: 0.0278 - accuracy: 0.9833
# Epoch 6: val_accuracy did not improve from 0.96667
# 45/45 [==============================] - 12s 263ms/step - loss: 0.0278 - accuracy: 0.9833 - val_loss: 0.0541 - val_accuracy: 0.9667 - lr: 2.5000e-05
# Epoch 7/100
# 45/45 [==============================] - ETA: 0s - loss: 0.0161 - accuracy: 0.9917
# Epoch 7: val_accuracy did not improve from 0.96667
# 45/45 [==============================] - 12s 263ms/step - loss: 0.0161 - accuracy: 0.9917 - val_loss: 0.1962 - val_accuracy: 0.9000 - lr: 2.5000e-05
# Epoch 8/100
# 45/45 [==============================] - ETA: 0s - loss: 0.0094 - accuracy: 1.0000
# Epoch 8: val_accuracy did not improve from 0.96667
# 45/45 [==============================] - 12s 257ms/step - loss: 0.0094 - accuracy: 1.0000 - val_loss: 0.0940 - val_accuracy: 0.9556 - lr: 2.5000e-05
# Epoch 9/100
# 45/45 [==============================] - ETA: 0s - loss: 0.0157 - accuracy: 0.9944
# Epoch 9: val_accuracy did not improve from 0.96667
# 45/45 [==============================] - 12s 256ms/step - loss: 0.0157 - accuracy: 0.9944 - val_loss: 0.1035 - val_accuracy: 0.9444 - lr: 2.5000e-05
# Epoch 10/100
# 45/45 [==============================] - ETA: 0s - loss: 0.0094 - accuracy: 0.9944
# Epoch 10: val_accuracy did not improve from 0.96667
# 45/45 [==============================] - 12s 256ms/step - loss: 0.0094 - accuracy: 0.9944 - val_loss: 0.1017 - val_accuracy: 0.9444 - lr: 2.5000e-05
# Epoch 11/100
# 45/45 [==============================] - ETA: 0s - loss: 0.0109 - accuracy: 0.9972
# Epoch 11: val_accuracy did not improve from 0.96667
#
# Epoch 11: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-05.
# 45/45 [==============================] - 12s 257ms/step - loss: 0.0109 - accuracy: 0.9972 - val_loss: 0.0528 - val_accuracy: 0.9667 - lr: 2.5000e-05
# Epoch 12/100
# 45/45 [==============================] - ETA: 0s - loss: 0.0148 - accuracy: 0.9944
# Epoch 12: val_accuracy did not improve from 0.96667
# 45/45 [==============================] - 12s 257ms/step - loss: 0.0148 - accuracy: 0.9944 - val_loss: 0.0562 - val_accuracy: 0.9667 - lr: 1.2500e-05
# Epoch 13/100
# 45/45 [==============================] - ETA: 0s - loss: 0.0187 - accuracy: 0.9889
# Epoch 13: val_accuracy improved from 0.96667 to 0.97778, saving model to  Kmodel8_soft_pre_bi3.h5
# INFO:tensorflow:Assets written to:  Kmodel8_soft_pre_bi3.h5 /assets
# 45/45 [==============================] - 49s 1s/step - loss: 0.0187 - accuracy: 0.9889 - val_loss: 0.0346 - val_accuracy: 0.9778 - lr: 1.2500e-05
# Epoch 14/100
# 45/45 [==============================] - ETA: 0s - loss: 0.0075 - accuracy: 1.0000
# Epoch 14: val_accuracy did not improve from 0.97778
# 45/45 [==============================] - 12s 259ms/step - loss: 0.0075 - accuracy: 1.0000 - val_loss: 0.0347 - val_accuracy: 0.9778 - lr: 1.2500e-05
# Epoch 15/100
# 45/45 [==============================] - ETA: 0s - loss: 0.0104 - accuracy: 1.0000
# Epoch 15: val_accuracy did not improve from 0.97778
# 45/45 [==============================] - 12s 258ms/step - loss: 0.0104 - accuracy: 1.0000 - val_loss: 0.0718 - val_accuracy: 0.9667 - lr: 1.2500e-05
#               precision    recall  f1-score   support
#
#   Lungcancer       1.00      0.93      0.96        27
#       Normal       1.00      0.97      0.98        33
# Tuberculosis       0.91      1.00      0.95        30
#
#     accuracy                           0.97        90
#    macro avg       0.97      0.97      0.97        90
# weighted avg       0.97      0.97      0.97        90
#
# Fold #4
# Epoch 1/100
# 45/45 [==============================] - ETA: 0s - loss: 0.0204 - accuracy: 0.9944
# Epoch 1: val_accuracy improved from -inf to 0.98889, saving model to  Kmodel8_soft_pre_bi4.h5
# INFO:tensorflow:Assets written to:  Kmodel8_soft_pre_bi4.h5 /assets
# 45/45 [==============================] - 48s 1s/step - loss: 0.0204 - accuracy: 0.9944 - val_loss: 0.0273 - val_accuracy: 0.9889 - lr: 1.2500e-05
# Epoch 2/100
# 45/45 [==============================] - ETA: 0s - loss: 0.0038 - accuracy: 1.0000
# Epoch 2: val_accuracy did not improve from 0.98889
# 45/45 [==============================] - 12s 259ms/step - loss: 0.0038 - accuracy: 1.0000 - val_loss: 0.0231 - val_accuracy: 0.9889 - lr: 1.2500e-05
# Epoch 3/100
# 45/45 [==============================] - ETA: 0s - loss: 0.0288 - accuracy: 0.9861
# Epoch 3: val_accuracy did not improve from 0.98889
# 45/45 [==============================] - 12s 256ms/step - loss: 0.0288 - accuracy: 0.9861 - val_loss: 0.0176 - val_accuracy: 0.9889 - lr: 1.2500e-05
# Epoch 4/100
# 45/45 [==============================] - ETA: 0s - loss: 0.0070 - accuracy: 0.9972
# Epoch 4: val_accuracy improved from 0.98889 to 1.00000, saving model to  Kmodel8_soft_pre_bi4.h5
# INFO:tensorflow:Assets written to:  Kmodel8_soft_pre_bi4.h5 /assets
# 45/45 [==============================] - 49s 1s/step - loss: 0.0070 - accuracy: 0.9972 - val_loss: 0.0125 - val_accuracy: 1.0000 - lr: 1.2500e-05
# Epoch 5/100
# 45/45 [==============================] - ETA: 0s - loss: 0.0090 - accuracy: 0.9972
# Epoch 5: val_accuracy did not improve from 1.00000
# 45/45 [==============================] - 12s 258ms/step - loss: 0.0090 - accuracy: 0.9972 - val_loss: 0.0204 - val_accuracy: 0.9889 - lr: 1.2500e-05
# Epoch 6/100
# 45/45 [==============================] - ETA: 0s - loss: 0.0083 - accuracy: 0.9972
# Epoch 6: val_accuracy did not improve from 1.00000
# 45/45 [==============================] - 12s 257ms/step - loss: 0.0083 - accuracy: 0.9972 - val_loss: 0.0254 - val_accuracy: 0.9889 - lr: 1.2500e-05
# Epoch 7/100
# 45/45 [==============================] - ETA: 0s - loss: 0.0052 - accuracy: 1.0000
# Epoch 7: val_accuracy did not improve from 1.00000
# 45/45 [==============================] - 12s 265ms/step - loss: 0.0052 - accuracy: 1.0000 - val_loss: 0.0313 - val_accuracy: 0.9889 - lr: 1.2500e-05
# Epoch 8/100
# 45/45 [==============================] - ETA: 0s - loss: 0.0087 - accuracy: 0.9944
# Epoch 8: val_accuracy did not improve from 1.00000
# 45/45 [==============================] - 12s 266ms/step - loss: 0.0087 - accuracy: 0.9944 - val_loss: 0.0315 - val_accuracy: 0.9889 - lr: 1.2500e-05
# Epoch 9/100
# 45/45 [==============================] - ETA: 0s - loss: 0.0032 - accuracy: 1.0000
# Epoch 9: val_accuracy did not improve from 1.00000
# 45/45 [==============================] - 12s 264ms/step - loss: 0.0032 - accuracy: 1.0000 - val_loss: 0.0281 - val_accuracy: 0.9889 - lr: 1.2500e-05
# Epoch 10/100
# 45/45 [==============================] - ETA: 0s - loss: 0.0101 - accuracy: 0.9944
# Epoch 10: val_accuracy did not improve from 1.00000
#
# Epoch 10: ReduceLROnPlateau reducing learning rate to 1e-05.
# 45/45 [==============================] - 12s 268ms/step - loss: 0.0101 - accuracy: 0.9944 - val_loss: 0.0151 - val_accuracy: 0.9889 - lr: 1.2500e-05
# Epoch 11/100
# 45/45 [==============================] - ETA: 0s - loss: 0.0137 - accuracy: 0.9972
# Epoch 11: val_accuracy did not improve from 1.00000
# 45/45 [==============================] - 12s 262ms/step - loss: 0.0137 - accuracy: 0.9972 - val_loss: 0.0253 - val_accuracy: 0.9889 - lr: 1.0000e-05
# Epoch 12/100
# 45/45 [==============================] - ETA: 0s - loss: 0.0110 - accuracy: 0.9944
# Epoch 12: val_accuracy did not improve from 1.00000
# 45/45 [==============================] - 12s 256ms/step - loss: 0.0110 - accuracy: 0.9944 - val_loss: 0.0254 - val_accuracy: 0.9889 - lr: 1.0000e-05
# Epoch 13/100
# 45/45 [==============================] - ETA: 0s - loss: 0.0053 - accuracy: 1.0000
# Epoch 13: val_accuracy did not improve from 1.00000
# 45/45 [==============================] - 12s 259ms/step - loss: 0.0053 - accuracy: 1.0000 - val_loss: 0.0306 - val_accuracy: 0.9889 - lr: 1.0000e-05
# Epoch 14/100
# 45/45 [==============================] - ETA: 0s - loss: 0.0143 - accuracy: 0.9972
# Epoch 14: val_accuracy did not improve from 1.00000
# 45/45 [==============================] - 12s 258ms/step - loss: 0.0143 - accuracy: 0.9972 - val_loss: 0.0250 - val_accuracy: 0.9889 - lr: 1.0000e-05
# Epoch 15/100
# 45/45 [==============================] - ETA: 0s - loss: 0.0083 - accuracy: 0.9972
# Epoch 15: val_accuracy did not improve from 1.00000
# 45/45 [==============================] - 12s 261ms/step - loss: 0.0083 - accuracy: 0.9972 - val_loss: 0.0188 - val_accuracy: 0.9889 - lr: 1.0000e-05
#               precision    recall  f1-score   support
#
#   Lungcancer       1.00      0.97      0.98        30
#       Normal       1.00      1.00      1.00        31
# Tuberculosis       0.97      1.00      0.98        29
#
#     accuracy                           0.99        90
#    macro avg       0.99      0.99      0.99        90
# weighted avg       0.99      0.99      0.99        90
#
# Fold #5
# Epoch 1/100
# 45/45 [==============================] - ETA: 0s - loss: 0.0036 - accuracy: 1.0000
# Epoch 1: val_accuracy improved from -inf to 1.00000, saving model to  Kmodel8_soft_pre_bi5.h5
# INFO:tensorflow:Assets written to:  Kmodel8_soft_pre_bi5.h5 /assets
# 45/45 [==============================] - 48s 1s/step - loss: 0.0036 - accuracy: 1.0000 - val_loss: 0.0087 - val_accuracy: 1.0000 - lr: 1.0000e-05
# Epoch 2/100
# 45/45 [==============================] - ETA: 0s - loss: 0.0048 - accuracy: 1.0000
# Epoch 2: val_accuracy did not improve from 1.00000
# 45/45 [==============================] - 12s 257ms/step - loss: 0.0048 - accuracy: 1.0000 - val_loss: 0.0100 - val_accuracy: 1.0000 - lr: 1.0000e-05
# Epoch 3/100
# 45/45 [==============================] - ETA: 0s - loss: 0.0045 - accuracy: 1.0000
# Epoch 3: val_accuracy did not improve from 1.00000
# 45/45 [==============================] - 12s 255ms/step - loss: 0.0045 - accuracy: 1.0000 - val_loss: 0.0156 - val_accuracy: 0.9889 - lr: 1.0000e-05
# Epoch 4/100
# 45/45 [==============================] - ETA: 0s - loss: 0.0096 - accuracy: 0.9944
# Epoch 4: val_accuracy did not improve from 1.00000
# 45/45 [==============================] - 12s 255ms/step - loss: 0.0096 - accuracy: 0.9944 - val_loss: 0.0261 - val_accuracy: 0.9889 - lr: 1.0000e-05
# Epoch 5/100
# 45/45 [==============================] - ETA: 0s - loss: 0.0066 - accuracy: 1.0000
# Epoch 5: val_accuracy did not improve from 1.00000
# 45/45 [==============================] - 12s 257ms/step - loss: 0.0066 - accuracy: 1.0000 - val_loss: 0.0168 - val_accuracy: 0.9889 - lr: 1.0000e-05
# Epoch 6/100
# 45/45 [==============================] - ETA: 0s - loss: 0.0022 - accuracy: 1.0000
# Epoch 6: val_accuracy did not improve from 1.00000
# 45/45 [==============================] - 12s 258ms/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 0.0213 - val_accuracy: 0.9889 - lr: 1.0000e-05
# Epoch 7/100
# 45/45 [==============================] - ETA: 0s - loss: 0.0403 - accuracy: 0.9944
# Epoch 7: val_accuracy did not improve from 1.00000
# 45/45 [==============================] - 12s 258ms/step - loss: 0.0403 - accuracy: 0.9944 - val_loss: 0.0255 - val_accuracy: 0.9889 - lr: 1.0000e-05
# Epoch 8/100
# 45/45 [==============================] - ETA: 0s - loss: 0.0030 - accuracy: 0.9972
# Epoch 8: val_accuracy did not improve from 1.00000
# 45/45 [==============================] - 12s 257ms/step - loss: 0.0030 - accuracy: 0.9972 - val_loss: 0.0165 - val_accuracy: 0.9889 - lr: 1.0000e-05
# Epoch 9/100
# 45/45 [==============================] - ETA: 0s - loss: 0.0079 - accuracy: 0.9972
# Epoch 9: val_accuracy did not improve from 1.00000
# 45/45 [==============================] - 12s 258ms/step - loss: 0.0079 - accuracy: 0.9972 - val_loss: 0.0231 - val_accuracy: 0.9889 - lr: 1.0000e-05
# Epoch 10/100
# 45/45 [==============================] - ETA: 0s - loss: 0.0052 - accuracy: 0.9972
# Epoch 10: val_accuracy did not improve from 1.00000
# 45/45 [==============================] - 12s 258ms/step - loss: 0.0052 - accuracy: 0.9972 - val_loss: 0.0318 - val_accuracy: 0.9889 - lr: 1.0000e-05
# Epoch 11/100
# 45/45 [==============================] - ETA: 0s - loss: 0.0025 - accuracy: 1.0000
# Epoch 11: val_accuracy did not improve from 1.00000
# 45/45 [==============================] - 12s 259ms/step - loss: 0.0025 - accuracy: 1.0000 - val_loss: 0.0252 - val_accuracy: 0.9889 - lr: 1.0000e-05
# Epoch 12/100
# 45/45 [==============================] - ETA: 0s - loss: 0.0088 - accuracy: 0.9944
# Epoch 12: val_accuracy did not improve from 1.00000
# 45/45 [==============================] - 12s 263ms/step - loss: 0.0088 - accuracy: 0.9944 - val_loss: 0.0291 - val_accuracy: 0.9889 - lr: 1.0000e-05
# Epoch 13/100
# 45/45 [==============================] - ETA: 0s - loss: 0.0407 - accuracy: 0.9861
# Epoch 13: val_accuracy did not improve from 1.00000
# 45/45 [==============================] - 12s 261ms/step - loss: 0.0407 - accuracy: 0.9861 - val_loss: 0.0377 - val_accuracy: 0.9889 - lr: 1.0000e-05
# Epoch 14/100
# 45/45 [==============================] - ETA: 0s - loss: 0.0111 - accuracy: 0.9917
# Epoch 14: val_accuracy did not improve from 1.00000
# 45/45 [==============================] - 12s 260ms/step - loss: 0.0111 - accuracy: 0.9917 - val_loss: 0.0457 - val_accuracy: 0.9889 - lr: 1.0000e-05
# Epoch 15/100
# 45/45 [==============================] - ETA: 0s - loss: 0.0037 - accuracy: 1.0000
# Epoch 15: val_accuracy did not improve from 1.00000
# 45/45 [==============================] - 12s 259ms/step - loss: 0.0037 - accuracy: 1.0000 - val_loss: 0.0231 - val_accuracy: 0.9889 - lr: 1.0000e-05
#               precision    recall  f1-score   support
#
#   Lungcancer       1.00      0.97      0.98        31
#       Normal       1.00      1.00      1.00        28
# Tuberculosis       0.97      1.00      0.98        31
#
#     accuracy                           0.99        90
#    macro avg       0.99      0.99      0.99        90
# weighted avg       0.99      0.99      0.99        90
#
#               precision    recall  f1-score   support
#
#   Lungcancer       0.93      0.85      0.89       150
#       Normal       0.99      0.93      0.96       150
# Tuberculosis       0.84      0.96      0.89       150
#
#     accuracy                           0.91       450
#    macro avg       0.92      0.91      0.91       450
# weighted avg       0.92      0.91      0.91       450

# %%
H_Incep.history.keys()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy', 'lr'])

# %%
lr = H_Incep.history['lr']

plt.figure(figsize=(20,15))

plt.subplot(2, 2, 1)
plt.plot(lr, label = " Learning rate")

# %% [markdown]
# #### 8 soft pre bi adam

# %%
BS = 8
filepath = "Kmodel8_soft_pre_bi_adam.h5"                  ##

train_img_Incep = []
for ImageName in tqdm(data_train3['ImageName']):              
    image_path = All_3class_dir +'/' + ImageName                  
    img = cv2.imread(image_path)                                          
    img = cv2.resize(img, (299, 299))                                      
    train_img_Incep.append(img)
data_Incep = np.array(train_img_Incep, dtype="float32") / 255.0

labels_Incep = np.array(data_train3[['NameType']] )        
labels_Incep.shape = (len(labels_Incep),) 
le_Incep = LabelEncoder()                                                                     
labels_Incep = le_Incep.fit_transform(labels_Incep)                                         
labels_Incep = to_categorical(labels_Incep, num_classes=3)                   

aug = ImageDataGenerator( rotation_range=15,	width_shift_range=0.1, 	height_shift_range=0.1,
		shear_range=0.15, 	horizontal_flip=True, 	fill_mode="nearest")
                                                                                                           ## 
callback = EarlyStopping( monitor= "val_accuracy",    patience=15,       mode="max" , baseline=1.0)

# checkpoint = ModelCheckpoint(filepath, monitor='val_accuracy', verbose=1,   save_best_only=True, mode='max')
                                                                                                            ##
reduce_lr = ReduceLROnPlateau(monitor='val_accuracy', factor=0.5,   patience=6,     verbose=1, mode='max', min_lr=0.00001)
# Out:
# 100%|██████████| 450/450 [00:05<00:00, 89.52it/s]

# %%
base_model_Incep = tf.keras.applications.InceptionV3(input_shape=(299, 299, 3), include_top=False, weights="imagenet")
len(base_model_Incep.layers)

base_model_Incep.trainable = True
for layer in base_model_Incep.layers[:100]:    #fix w & bias in layer 0-100
    layer.trainable = False


#Add custom head
average_pooling_layer = tf.keras.layers.GlobalAveragePooling2D()(base_model_Incep.output)
prediction_layer = tf.keras.layers.Dense(units=3, activation="softmax")(average_pooling_layer)   # unit 3
model_Incep = tf.keras.models.Model(inputs=base_model_Incep.input, outputs=prediction_layer)

model_Incep.compile(optimizer=Adam(learning_rate=0.0001), loss="binary_crossentropy", metrics=["accuracy"])


### K-fold
kf_Incep = KFold(5, shuffle=True, random_state=40) 

oos_y = []
oos_pred = []
fold = 0

for train, test in kf_Incep.split(data_Incep):
    fold+=1   
    print(f"Fold #{fold}")

    filename = f" Kmodel8_soft_pre_bi_adam{fold}.h5 "
    checkpoint = ModelCheckpoint(filename, monitor='val_accuracy', verbose=1,   save_best_only=True, mode='max')
        
    x_train_Incep = data_Incep[train]
    y_train_Incep = labels_Incep[train]
    x_test_Incep = data_Incep[test]
    y_test_Incep = labels_Incep[test]

    H_Incep = model_Incep.fit( x=aug.flow(x_train_Incep, y_train_Incep, batch_size=BS),
	                                            validation_data=(x_test_Incep, y_test_Incep),
	                                            steps_per_epoch=len(x_train_Incep) // BS,
	                                            epochs=100,  callbacks = [callback,checkpoint,reduce_lr])

    pred_Incep = model_Incep.predict(x_test_Incep)
    
    oos_y.append(y_test_Incep)
    oos_pred.append(pred_Incep)  
    print(classification_report(y_test_Incep.argmax(axis=1),	                #แสดง report ค่า acc, recall, ...
                                        pred_Incep.argmax(axis=1),  
                                        target_names=le_Incep.classes_))
    
oos_y = np.concatenate(oos_y)
oos_pred = np.concatenate(oos_pred)
print(classification_report(oos_y.argmax(axis=1), oos_pred.argmax(axis=1),  target_names=le_Incep.classes_))
# Out:
# Fold #1
# Epoch 1/100
# 45/45 [==============================] - ETA: 0s - loss: 0.5174 - accuracy: 0.6167
# Epoch 1: val_accuracy improved from -inf to 0.55556, saving model to  Kmodel8_soft_pre_bi_adam1.h5
# INFO:tensorflow:Assets written to:  Kmodel8_soft_pre_bi_adam1.h5 /assets
# 45/45 [==============================] - 60s 1s/step - loss: 0.5174 - accuracy: 0.6167 - val_loss: 0.7293 - val_accuracy: 0.5556 - lr: 1.0000e-04
# Epoch 2/100
# 45/45 [==============================] - ETA: 0s - loss: 0.3374 - accuracy: 0.7806
# Epoch 2: val_accuracy improved from 0.55556 to 0.71111, saving model to  Kmodel8_soft_pre_bi_adam1.h5
# INFO:tensorflow:Assets written to:  Kmodel8_soft_pre_bi_adam1.h5 /assets
# 45/45 [==============================] - 50s 1s/step - loss: 0.3374 - accuracy: 0.7806 - val_loss: 0.4507 - val_accuracy: 0.7111 - lr: 1.0000e-04
# Epoch 3/100
# 45/45 [==============================] - ETA: 0s - loss: 0.2482 - accuracy: 0.8500
# Epoch 3: val_accuracy did not improve from 0.71111
# 45/45 [==============================] - 11s 249ms/step - loss: 0.2482 - accuracy: 0.8500 - val_loss: 0.5646 - val_accuracy: 0.6667 - lr: 1.0000e-04
# Epoch 4/100
# 45/45 [==============================] - ETA: 0s - loss: 0.2102 - accuracy: 0.8806
# Epoch 4: val_accuracy did not improve from 0.71111
# 45/45 [==============================] - 11s 249ms/step - loss: 0.2102 - accuracy: 0.8806 - val_loss: 0.7987 - val_accuracy: 0.6889 - lr: 1.0000e-04
# Epoch 5/100
# 45/45 [==============================] - ETA: 0s - loss: 0.2300 - accuracy: 0.8778
# Epoch 5: val_accuracy improved from 0.71111 to 0.72222, saving model to  Kmodel8_soft_pre_bi_adam1.h5
# INFO:tensorflow:Assets written to:  Kmodel8_soft_pre_bi_adam1.h5 /assets
# 45/45 [==============================] - 49s 1s/step - loss: 0.2300 - accuracy: 0.8778 - val_loss: 0.6451 - val_accuracy: 0.7222 - lr: 1.0000e-04
# Epoch 6/100
# 45/45 [==============================] - ETA: 0s - loss: 0.1439 - accuracy: 0.9194
# Epoch 6: val_accuracy improved from 0.72222 to 0.90000, saving model to  Kmodel8_soft_pre_bi_adam1.h5
# INFO:tensorflow:Assets written to:  Kmodel8_soft_pre_bi_adam1.h5 /assets
# 45/45 [==============================] - 49s 1s/step - loss: 0.1439 - accuracy: 0.9194 - val_loss: 0.1641 - val_accuracy: 0.9000 - lr: 1.0000e-04
# Epoch 7/100
# 45/45 [==============================] - ETA: 0s - loss: 0.1107 - accuracy: 0.9417
# Epoch 7: val_accuracy did not improve from 0.90000
# 45/45 [==============================] - 11s 251ms/step - loss: 0.1107 - accuracy: 0.9417 - val_loss: 0.3551 - val_accuracy: 0.8222 - lr: 1.0000e-04
# Epoch 8/100
# 45/45 [==============================] - ETA: 0s - loss: 0.1623 - accuracy: 0.9000
# Epoch 8: val_accuracy did not improve from 0.90000
# 45/45 [==============================] - 11s 249ms/step - loss: 0.1623 - accuracy: 0.9000 - val_loss: 0.8135 - val_accuracy: 0.5667 - lr: 1.0000e-04
# Epoch 9/100
# 45/45 [==============================] - ETA: 0s - loss: 0.1232 - accuracy: 0.9417
# Epoch 9: val_accuracy did not improve from 0.90000
# 45/45 [==============================] - 11s 247ms/step - loss: 0.1232 - accuracy: 0.9417 - val_loss: 0.4716 - val_accuracy: 0.7556 - lr: 1.0000e-04
# Epoch 10/100
# 45/45 [==============================] - ETA: 0s - loss: 0.0899 - accuracy: 0.9500
# Epoch 10: val_accuracy did not improve from 0.90000
# 45/45 [==============================] - 11s 250ms/step - loss: 0.0899 - accuracy: 0.9500 - val_loss: 0.6470 - val_accuracy: 0.7222 - lr: 1.0000e-04
# Epoch 11/100
# 45/45 [==============================] - ETA: 0s - loss: 0.0866 - accuracy: 0.9528
# Epoch 11: val_accuracy did not improve from 0.90000
# 45/45 [==============================] - 11s 249ms/step - loss: 0.0866 - accuracy: 0.9528 - val_loss: 0.7742 - val_accuracy: 0.6667 - lr: 1.0000e-04
# Epoch 12/100
# 45/45 [==============================] - ETA: 0s - loss: 0.1014 - accuracy: 0.9472
# Epoch 12: val_accuracy did not improve from 0.90000
#
# Epoch 12: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 45/45 [==============================] - 11s 246ms/step - loss: 0.1014 - accuracy: 0.9472 - val_loss: 0.7005 - val_accuracy: 0.6889 - lr: 1.0000e-04
# Epoch 13/100
# 45/45 [==============================] - ETA: 0s - loss: 0.0892 - accuracy: 0.9583
# Epoch 13: val_accuracy did not improve from 0.90000
# 45/45 [==============================] - 11s 249ms/step - loss: 0.0892 - accuracy: 0.9583 - val_loss: 0.5443 - val_accuracy: 0.7667 - lr: 5.0000e-05
# Epoch 14/100
# 45/45 [==============================] - ETA: 0s - loss: 0.0770 - accuracy: 0.9611
# Epoch 14: val_accuracy did not improve from 0.90000
# 45/45 [==============================] - 11s 248ms/step - loss: 0.0770 - accuracy: 0.9611 - val_loss: 0.6748 - val_accuracy: 0.6444 - lr: 5.0000e-05
# Epoch 15/100
# 45/45 [==============================] - ETA: 0s - loss: 0.0433 - accuracy: 0.9917
# Epoch 15: val_accuracy did not improve from 0.90000
# 45/45 [==============================] - 12s 255ms/step - loss: 0.0433 - accuracy: 0.9917 - val_loss: 0.4947 - val_accuracy: 0.7556 - lr: 5.0000e-05
#               precision    recall  f1-score   support
#
#   Lungcancer       1.00      0.64      0.78        28
#       Normal       0.90      0.61      0.73        31
# Tuberculosis       0.61      1.00      0.76        31
#
#     accuracy                           0.76        90
#    macro avg       0.84      0.75      0.76        90
# weighted avg       0.83      0.76      0.76        90
#
# Fold #2
# Epoch 1/100
# 45/45 [==============================] - ETA: 0s - loss: 0.0832 - accuracy: 0.9667
# Epoch 1: val_accuracy improved from -inf to 0.90000, saving model to  Kmodel8_soft_pre_bi_adam2.h5
# INFO:tensorflow:Assets written to:  Kmodel8_soft_pre_bi_adam2.h5 /assets
# 45/45 [==============================] - 50s 1s/step - loss: 0.0832 - accuracy: 0.9667 - val_loss: 0.1831 - val_accuracy: 0.9000 - lr: 5.0000e-05
# Epoch 2/100
# 45/45 [==============================] - ETA: 0s - loss: 0.1003 - accuracy: 0.9583
# Epoch 2: val_accuracy did not improve from 0.90000
# 45/45 [==============================] - 11s 245ms/step - loss: 0.1003 - accuracy: 0.9583 - val_loss: 0.2981 - val_accuracy: 0.7778 - lr: 5.0000e-05
# Epoch 3/100
# 45/45 [==============================] - ETA: 0s - loss: 0.0521 - accuracy: 0.9806
# Epoch 3: val_accuracy did not improve from 0.90000
# 45/45 [==============================] - 11s 246ms/step - loss: 0.0521 - accuracy: 0.9806 - val_loss: 0.3432 - val_accuracy: 0.8111 - lr: 5.0000e-05
# Epoch 4/100
# 45/45 [==============================] - ETA: 0s - loss: 0.0545 - accuracy: 0.9722
# Epoch 4: val_accuracy improved from 0.90000 to 0.95556, saving model to  Kmodel8_soft_pre_bi_adam2.h5
# INFO:tensorflow:Assets written to:  Kmodel8_soft_pre_bi_adam2.h5 /assets
# 45/45 [==============================] - 49s 1s/step - loss: 0.0545 - accuracy: 0.9722 - val_loss: 0.0804 - val_accuracy: 0.9556 - lr: 5.0000e-05
# Epoch 5/100
# 45/45 [==============================] - ETA: 0s - loss: 0.0657 - accuracy: 0.9722
# Epoch 5: val_accuracy did not improve from 0.95556
# 45/45 [==============================] - 11s 246ms/step - loss: 0.0657 - accuracy: 0.9722 - val_loss: 0.1760 - val_accuracy: 0.8556 - lr: 5.0000e-05
# Epoch 6/100
# 45/45 [==============================] - ETA: 0s - loss: 0.0496 - accuracy: 0.9778
# Epoch 6: val_accuracy did not improve from 0.95556
# 45/45 [==============================] - 11s 245ms/step - loss: 0.0496 - accuracy: 0.9778 - val_loss: 0.2118 - val_accuracy: 0.8556 - lr: 5.0000e-05
# Epoch 7/100
# 45/45 [==============================] - ETA: 0s - loss: 0.0451 - accuracy: 0.9833
# Epoch 7: val_accuracy did not improve from 0.95556
# 45/45 [==============================] - 11s 245ms/step - loss: 0.0451 - accuracy: 0.9833 - val_loss: 0.2580 - val_accuracy: 0.8333 - lr: 5.0000e-05
# Epoch 8/100
# 45/45 [==============================] - ETA: 0s - loss: 0.0558 - accuracy: 0.9778
# Epoch 8: val_accuracy did not improve from 0.95556
# 45/45 [==============================] - 11s 248ms/step - loss: 0.0558 - accuracy: 0.9778 - val_loss: 0.3223 - val_accuracy: 0.8333 - lr: 5.0000e-05
# Epoch 9/100
# 45/45 [==============================] - ETA: 0s - loss: 0.0528 - accuracy: 0.9667
# Epoch 9: val_accuracy did not improve from 0.95556
# 45/45 [==============================] - 11s 250ms/step - loss: 0.0528 - accuracy: 0.9667 - val_loss: 0.6967 - val_accuracy: 0.7333 - lr: 5.0000e-05
# Epoch 10/100
# 45/45 [==============================] - ETA: 0s - loss: 0.0667 - accuracy: 0.9583
# Epoch 10: val_accuracy did not improve from 0.95556
#
# Epoch 10: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# 45/45 [==============================] - 11s 247ms/step - loss: 0.0667 - accuracy: 0.9583 - val_loss: 0.1517 - val_accuracy: 0.9111 - lr: 5.0000e-05
# Epoch 11/100
# 45/45 [==============================] - ETA: 0s - loss: 0.0499 - accuracy: 0.9806
# Epoch 11: val_accuracy did not improve from 0.95556
# 45/45 [==============================] - 11s 245ms/step - loss: 0.0499 - accuracy: 0.9806 - val_loss: 0.1032 - val_accuracy: 0.9333 - lr: 2.5000e-05
# Epoch 12/100
# 45/45 [==============================] - ETA: 0s - loss: 0.0302 - accuracy: 0.9944
# Epoch 12: val_accuracy did not improve from 0.95556
# 45/45 [==============================] - 11s 246ms/step - loss: 0.0302 - accuracy: 0.9944 - val_loss: 0.0801 - val_accuracy: 0.9333 - lr: 2.5000e-05
# Epoch 13/100
# 45/45 [==============================] - ETA: 0s - loss: 0.0166 - accuracy: 1.0000
# Epoch 13: val_accuracy did not improve from 0.95556
# 45/45 [==============================] - 11s 247ms/step - loss: 0.0166 - accuracy: 1.0000 - val_loss: 0.0984 - val_accuracy: 0.9333 - lr: 2.5000e-05
# Epoch 14/100
# 45/45 [==============================] - ETA: 0s - loss: 0.0285 - accuracy: 0.9917
# Epoch 14: val_accuracy did not improve from 0.95556
# 45/45 [==============================] - 11s 246ms/step - loss: 0.0285 - accuracy: 0.9917 - val_loss: 0.0999 - val_accuracy: 0.9333 - lr: 2.5000e-05
# Epoch 15/100
# 45/45 [==============================] - ETA: 0s - loss: 0.0167 - accuracy: 0.9972
# Epoch 15: val_accuracy did not improve from 0.95556
# 45/45 [==============================] - 11s 245ms/step - loss: 0.0167 - accuracy: 0.9972 - val_loss: 0.2030 - val_accuracy: 0.8444 - lr: 2.5000e-05
#               precision    recall  f1-score   support
#
#   Lungcancer       1.00      0.59      0.74        34
#       Normal       1.00      1.00      1.00        27
# Tuberculosis       0.67      1.00      0.81        29
#
#     accuracy                           0.84        90
#    macro avg       0.89      0.86      0.85        90
# weighted avg       0.90      0.84      0.84        90
#
# Fold #3
# Epoch 1/100
# 45/45 [==============================] - ETA: 0s - loss: 0.0419 - accuracy: 0.9833
# Epoch 1: val_accuracy improved from -inf to 0.88889, saving model to  Kmodel8_soft_pre_bi_adam3.h5
# INFO:tensorflow:Assets written to:  Kmodel8_soft_pre_bi_adam3.h5 /assets
# 45/45 [==============================] - 50s 1s/step - loss: 0.0419 - accuracy: 0.9833 - val_loss: 0.2132 - val_accuracy: 0.8889 - lr: 2.5000e-05
# Epoch 2/100
# 45/45 [==============================] - ETA: 0s - loss: 0.0319 - accuracy: 0.9861
# Epoch 2: val_accuracy improved from 0.88889 to 0.97778, saving model to  Kmodel8_soft_pre_bi_adam3.h5
# INFO:tensorflow:Assets written to:  Kmodel8_soft_pre_bi_adam3.h5 /assets
# 45/45 [==============================] - 50s 1s/step - loss: 0.0319 - accuracy: 0.9861 - val_loss: 0.0751 - val_accuracy: 0.9778 - lr: 2.5000e-05
# Epoch 3/100
# 45/45 [==============================] - ETA: 0s - loss: 0.0392 - accuracy: 0.9889
# Epoch 3: val_accuracy did not improve from 0.97778
# 45/45 [==============================] - 11s 249ms/step - loss: 0.0392 - accuracy: 0.9889 - val_loss: 0.0972 - val_accuracy: 0.9667 - lr: 2.5000e-05
# Epoch 4/100
# 45/45 [==============================] - ETA: 0s - loss: 0.0296 - accuracy: 0.9861
# Epoch 4: val_accuracy did not improve from 0.97778
# 45/45 [==============================] - 11s 247ms/step - loss: 0.0296 - accuracy: 0.9861 - val_loss: 0.0373 - val_accuracy: 0.9778 - lr: 2.5000e-05
# Epoch 5/100
# 45/45 [==============================] - ETA: 0s - loss: 0.0264 - accuracy: 0.9944
# Epoch 5: val_accuracy did not improve from 0.97778
# 45/45 [==============================] - 11s 246ms/step - loss: 0.0264 - accuracy: 0.9944 - val_loss: 0.0700 - val_accuracy: 0.9556 - lr: 2.5000e-05
# Epoch 6/100
# 45/45 [==============================] - ETA: 0s - loss: 0.0367 - accuracy: 0.9889
# Epoch 6: val_accuracy did not improve from 0.97778
# 45/45 [==============================] - 11s 245ms/step - loss: 0.0367 - accuracy: 0.9889 - val_loss: 0.0515 - val_accuracy: 0.9667 - lr: 2.5000e-05
# Epoch 7/100
# 45/45 [==============================] - ETA: 0s - loss: 0.0311 - accuracy: 0.9889
# Epoch 7: val_accuracy improved from 0.97778 to 0.98889, saving model to  Kmodel8_soft_pre_bi_adam3.h5
# INFO:tensorflow:Assets written to:  Kmodel8_soft_pre_bi_adam3.h5 /assets
# 45/45 [==============================] - 49s 1s/step - loss: 0.0311 - accuracy: 0.9889 - val_loss: 0.0290 - val_accuracy: 0.9889 - lr: 2.5000e-05
# Epoch 8/100
# 45/45 [==============================] - ETA: 0s - loss: 0.0288 - accuracy: 0.9861
# Epoch 8: val_accuracy did not improve from 0.98889
# 45/45 [==============================] - 11s 250ms/step - loss: 0.0288 - accuracy: 0.9861 - val_loss: 0.0914 - val_accuracy: 0.9444 - lr: 2.5000e-05
# Epoch 9/100
# 45/45 [==============================] - ETA: 0s - loss: 0.0228 - accuracy: 0.9972
# Epoch 9: val_accuracy did not improve from 0.98889
# 45/45 [==============================] - 11s 251ms/step - loss: 0.0228 - accuracy: 0.9972 - val_loss: 0.0576 - val_accuracy: 0.9778 - lr: 2.5000e-05
# Epoch 10/100
# 45/45 [==============================] - ETA: 0s - loss: 0.0263 - accuracy: 0.9861
# Epoch 10: val_accuracy did not improve from 0.98889
# 45/45 [==============================] - 11s 251ms/step - loss: 0.0263 - accuracy: 0.9861 - val_loss: 0.0419 - val_accuracy: 0.9889 - lr: 2.5000e-05
# Epoch 11/100
# 45/45 [==============================] - ETA: 0s - loss: 0.0136 - accuracy: 1.0000
# Epoch 11: val_accuracy did not improve from 0.98889
# 45/45 [==============================] - 11s 249ms/step - loss: 0.0136 - accuracy: 1.0000 - val_loss: 0.0586 - val_accuracy: 0.9667 - lr: 2.5000e-05
# Epoch 12/100
# 45/45 [==============================] - ETA: 0s - loss: 0.0098 - accuracy: 1.0000
# Epoch 12: val_accuracy did not improve from 0.98889
# 45/45 [==============================] - 11s 250ms/step - loss: 0.0098 - accuracy: 1.0000 - val_loss: 0.0827 - val_accuracy: 0.9556 - lr: 2.5000e-05
# Epoch 13/100
# 45/45 [==============================] - ETA: 0s - loss: 0.0118 - accuracy: 1.0000
# Epoch 13: val_accuracy did not improve from 0.98889
#
# Epoch 13: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-05.
# 45/45 [==============================] - 11s 249ms/step - loss: 0.0118 - accuracy: 1.0000 - val_loss: 0.0356 - val_accuracy: 0.9778 - lr: 2.5000e-05
# Epoch 14/100
# 45/45 [==============================] - ETA: 0s - loss: 0.0117 - accuracy: 0.9972
# Epoch 14: val_accuracy did not improve from 0.98889
# 45/45 [==============================] - 11s 245ms/step - loss: 0.0117 - accuracy: 0.9972 - val_loss: 0.0572 - val_accuracy: 0.9778 - lr: 1.2500e-05
# Epoch 15/100
# 45/45 [==============================] - ETA: 0s - loss: 0.0246 - accuracy: 0.9861
# Epoch 15: val_accuracy did not improve from 0.98889
# 45/45 [==============================] - 11s 249ms/step - loss: 0.0246 - accuracy: 0.9861 - val_loss: 0.0901 - val_accuracy: 0.9444 - lr: 1.2500e-05
#               precision    recall  f1-score   support
#
#   Lungcancer       1.00      0.93      0.96        27
#       Normal       1.00      0.91      0.95        33
# Tuberculosis       0.86      1.00      0.92        30
#
#     accuracy                           0.94        90
#    macro avg       0.95      0.95      0.95        90
# weighted avg       0.95      0.94      0.95        90
#
# Fold #4
# Epoch 1/100
# 45/45 [==============================] - ETA: 0s - loss: 0.0197 - accuracy: 0.9917
# Epoch 1: val_accuracy improved from -inf to 0.95556, saving model to  Kmodel8_soft_pre_bi_adam4.h5
# INFO:tensorflow:Assets written to:  Kmodel8_soft_pre_bi_adam4.h5 /assets
# 45/45 [==============================] - 50s 1s/step - loss: 0.0197 - accuracy: 0.9917 - val_loss: 0.0664 - val_accuracy: 0.9556 - lr: 1.2500e-05
# Epoch 2/100
# 45/45 [==============================] - ETA: 0s - loss: 0.0191 - accuracy: 0.9889
# Epoch 2: val_accuracy improved from 0.95556 to 0.96667, saving model to  Kmodel8_soft_pre_bi_adam4.h5
# INFO:tensorflow:Assets written to:  Kmodel8_soft_pre_bi_adam4.h5 /assets
# 45/45 [==============================] - 51s 1s/step - loss: 0.0191 - accuracy: 0.9889 - val_loss: 0.0476 - val_accuracy: 0.9667 - lr: 1.2500e-05
# Epoch 3/100
# 45/45 [==============================] - ETA: 0s - loss: 0.0112 - accuracy: 1.0000
# Epoch 3: val_accuracy improved from 0.96667 to 0.98889, saving model to  Kmodel8_soft_pre_bi_adam4.h5
# INFO:tensorflow:Assets written to:  Kmodel8_soft_pre_bi_adam4.h5 /assets
# 45/45 [==============================] - 49s 1s/step - loss: 0.0112 - accuracy: 1.0000 - val_loss: 0.0432 - val_accuracy: 0.9889 - lr: 1.2500e-05
# Epoch 4/100
# 45/45 [==============================] - ETA: 0s - loss: 0.0062 - accuracy: 1.0000
# Epoch 4: val_accuracy did not improve from 0.98889
# 45/45 [==============================] - 11s 246ms/step - loss: 0.0062 - accuracy: 1.0000 - val_loss: 0.0472 - val_accuracy: 0.9778 - lr: 1.2500e-05
# Epoch 5/100
# 45/45 [==============================] - ETA: 0s - loss: 0.0149 - accuracy: 1.0000
# Epoch 5: val_accuracy did not improve from 0.98889
# 45/45 [==============================] - 11s 248ms/step - loss: 0.0149 - accuracy: 1.0000 - val_loss: 0.0424 - val_accuracy: 0.9778 - lr: 1.2500e-05
# Epoch 6/100
# 45/45 [==============================] - ETA: 0s - loss: 0.0112 - accuracy: 1.0000
# Epoch 6: val_accuracy did not improve from 0.98889
# 45/45 [==============================] - 11s 246ms/step - loss: 0.0112 - accuracy: 1.0000 - val_loss: 0.0500 - val_accuracy: 0.9778 - lr: 1.2500e-05
# Epoch 7/100
# 45/45 [==============================] - ETA: 0s - loss: 0.0130 - accuracy: 1.0000
# Epoch 7: val_accuracy did not improve from 0.98889
# 45/45 [==============================] - 11s 249ms/step - loss: 0.0130 - accuracy: 1.0000 - val_loss: 0.0597 - val_accuracy: 0.9556 - lr: 1.2500e-05
# Epoch 8/100
# 45/45 [==============================] - ETA: 0s - loss: 0.0231 - accuracy: 0.9944
# Epoch 8: val_accuracy did not improve from 0.98889
# 45/45 [==============================] - 11s 250ms/step - loss: 0.0231 - accuracy: 0.9944 - val_loss: 0.0643 - val_accuracy: 0.9556 - lr: 1.2500e-05
# Epoch 9/100
# 45/45 [==============================] - ETA: 0s - loss: 0.0091 - accuracy: 1.0000
# Epoch 9: val_accuracy did not improve from 0.98889
#
# Epoch 9: ReduceLROnPlateau reducing learning rate to 1e-05.
# 45/45 [==============================] - 11s 250ms/step - loss: 0.0091 - accuracy: 1.0000 - val_loss: 0.0592 - val_accuracy: 0.9667 - lr: 1.2500e-05
# Epoch 10/100
# 45/45 [==============================] - ETA: 0s - loss: 0.0200 - accuracy: 0.9917
# Epoch 10: val_accuracy did not improve from 0.98889
# 45/45 [==============================] - 11s 249ms/step - loss: 0.0200 - accuracy: 0.9917 - val_loss: 0.0357 - val_accuracy: 0.9889 - lr: 1.0000e-05
# Epoch 11/100
# 45/45 [==============================] - ETA: 0s - loss: 0.0188 - accuracy: 0.9972
# Epoch 11: val_accuracy did not improve from 0.98889
# 45/45 [==============================] - 11s 249ms/step - loss: 0.0188 - accuracy: 0.9972 - val_loss: 0.0723 - val_accuracy: 0.9556 - lr: 1.0000e-05
# Epoch 12/100
# 45/45 [==============================] - ETA: 0s - loss: 0.0143 - accuracy: 0.9972
# Epoch 12: val_accuracy did not improve from 0.98889
# 45/45 [==============================] - 11s 248ms/step - loss: 0.0143 - accuracy: 0.9972 - val_loss: 0.0553 - val_accuracy: 0.9778 - lr: 1.0000e-05
# Epoch 13/100
# 45/45 [==============================] - ETA: 0s - loss: 0.0107 - accuracy: 0.9972
# Epoch 13: val_accuracy did not improve from 0.98889
# 45/45 [==============================] - 11s 251ms/step - loss: 0.0107 - accuracy: 0.9972 - val_loss: 0.0505 - val_accuracy: 0.9778 - lr: 1.0000e-05
# Epoch 14/100
# 45/45 [==============================] - ETA: 0s - loss: 0.0081 - accuracy: 1.0000
# Epoch 14: val_accuracy did not improve from 0.98889
# 45/45 [==============================] - 11s 251ms/step - loss: 0.0081 - accuracy: 1.0000 - val_loss: 0.0421 - val_accuracy: 0.9778 - lr: 1.0000e-05
# Epoch 15/100
# 45/45 [==============================] - ETA: 0s - loss: 0.0100 - accuracy: 1.0000
# Epoch 15: val_accuracy did not improve from 0.98889
# 45/45 [==============================] - 11s 247ms/step - loss: 0.0100 - accuracy: 1.0000 - val_loss: 0.0583 - val_accuracy: 0.9667 - lr: 1.0000e-05
#               precision    recall  f1-score   support
#
#   Lungcancer       1.00      0.93      0.97        30
#       Normal       1.00      0.97      0.98        31
# Tuberculosis       0.91      1.00      0.95        29
#
#     accuracy                           0.97        90
#    macro avg       0.97      0.97      0.97        90
# weighted avg       0.97      0.97      0.97        90
#
# Fold #5
# Epoch 1/100
# 45/45 [==============================] - ETA: 0s - loss: 0.0086 - accuracy: 1.0000
# Epoch 1: val_accuracy improved from -inf to 1.00000, saving model to  Kmodel8_soft_pre_bi_adam5.h5
# INFO:tensorflow:Assets written to:  Kmodel8_soft_pre_bi_adam5.h5 /assets
# 45/45 [==============================] - 52s 1s/step - loss: 0.0086 - accuracy: 1.0000 - val_loss: 0.0273 - val_accuracy: 1.0000 - lr: 1.0000e-05
# Epoch 2/100
# 45/45 [==============================] - ETA: 0s - loss: 0.0151 - accuracy: 0.9944
# Epoch 2: val_accuracy did not improve from 1.00000
# 45/45 [==============================] - 12s 264ms/step - loss: 0.0151 - accuracy: 0.9944 - val_loss: 0.0343 - val_accuracy: 1.0000 - lr: 1.0000e-05
# Epoch 3/100
# 45/45 [==============================] - ETA: 0s - loss: 0.0137 - accuracy: 0.9972
# Epoch 3: val_accuracy did not improve from 1.00000
# 45/45 [==============================] - 12s 261ms/step - loss: 0.0137 - accuracy: 0.9972 - val_loss: 0.0329 - val_accuracy: 0.9889 - lr: 1.0000e-05
# Epoch 4/100
# 45/45 [==============================] - ETA: 0s - loss: 0.0086 - accuracy: 1.0000
# Epoch 4: val_accuracy did not improve from 1.00000
# 45/45 [==============================] - 12s 259ms/step - loss: 0.0086 - accuracy: 1.0000 - val_loss: 0.0329 - val_accuracy: 1.0000 - lr: 1.0000e-05
# Epoch 5/100
# 45/45 [==============================] - ETA: 0s - loss: 0.0161 - accuracy: 0.9917
# Epoch 5: val_accuracy did not improve from 1.00000
# 45/45 [==============================] - 12s 256ms/step - loss: 0.0161 - accuracy: 0.9917 - val_loss: 0.0347 - val_accuracy: 1.0000 - lr: 1.0000e-05
# Epoch 6/100
# 45/45 [==============================] - ETA: 0s - loss: 0.0072 - accuracy: 0.9972
# Epoch 6: val_accuracy did not improve from 1.00000
# 45/45 [==============================] - 11s 249ms/step - loss: 0.0072 - accuracy: 0.9972 - val_loss: 0.0312 - val_accuracy: 1.0000 - lr: 1.0000e-05
# Epoch 7/100
# 45/45 [==============================] - ETA: 0s - loss: 0.0220 - accuracy: 0.9861
# Epoch 7: val_accuracy did not improve from 1.00000
# 45/45 [==============================] - 11s 248ms/step - loss: 0.0220 - accuracy: 0.9861 - val_loss: 0.0245 - val_accuracy: 1.0000 - lr: 1.0000e-05
# Epoch 8/100
# 45/45 [==============================] - ETA: 0s - loss: 0.0097 - accuracy: 0.9972
# Epoch 8: val_accuracy did not improve from 1.00000
# 45/45 [==============================] - 12s 256ms/step - loss: 0.0097 - accuracy: 0.9972 - val_loss: 0.0420 - val_accuracy: 1.0000 - lr: 1.0000e-05
# Epoch 9/100
# 45/45 [==============================] - ETA: 0s - loss: 0.0101 - accuracy: 1.0000
# Epoch 9: val_accuracy did not improve from 1.00000
# 45/45 [==============================] - 11s 253ms/step - loss: 0.0101 - accuracy: 1.0000 - val_loss: 0.0486 - val_accuracy: 0.9889 - lr: 1.0000e-05
# Epoch 10/100
# 45/45 [==============================] - ETA: 0s - loss: 0.0133 - accuracy: 1.0000
# Epoch 10: val_accuracy did not improve from 1.00000
# 45/45 [==============================] - 11s 251ms/step - loss: 0.0133 - accuracy: 1.0000 - val_loss: 0.0343 - val_accuracy: 1.0000 - lr: 1.0000e-05
# Epoch 11/100
# 45/45 [==============================] - ETA: 0s - loss: 0.0130 - accuracy: 0.9972
# Epoch 11: val_accuracy did not improve from 1.00000
# 45/45 [==============================] - 11s 251ms/step - loss: 0.0130 - accuracy: 0.9972 - val_loss: 0.0243 - val_accuracy: 1.0000 - lr: 1.0000e-05
# Epoch 12/100
# 45/45 [==============================] - ETA: 0s - loss: 0.0106 - accuracy: 0.9972
# Epoch 12: val_accuracy did not improve from 1.00000
# 45/45 [==============================] - 11s 252ms/step - loss: 0.0106 - accuracy: 0.9972 - val_loss: 0.0244 - val_accuracy: 1.0000 - lr: 1.0000e-05
# Epoch 13/100
# 45/45 [==============================] - ETA: 0s - loss: 0.0079 - accuracy: 1.0000
# Epoch 13: val_accuracy did not improve from 1.00000
# 45/45 [==============================] - 12s 258ms/step - loss: 0.0079 - accuracy: 1.0000 - val_loss: 0.0197 - val_accuracy: 1.0000 - lr: 1.0000e-05
# Epoch 14/100
# 45/45 [==============================] - ETA: 0s - loss: 0.0110 - accuracy: 1.0000
# Epoch 14: val_accuracy did not improve from 1.00000
# 45/45 [==============================] - 12s 254ms/step - loss: 0.0110 - accuracy: 1.0000 - val_loss: 0.0226 - val_accuracy: 1.0000 - lr: 1.0000e-05
# Epoch 15/100
# 45/45 [==============================] - ETA: 0s - loss: 0.0121 - accuracy: 1.0000
# Epoch 15: val_accuracy did not improve from 1.00000
# 45/45 [==============================] - 12s 257ms/step - loss: 0.0121 - accuracy: 1.0000 - val_loss: 0.0268 - val_accuracy: 1.0000 - lr: 1.0000e-05
#               precision    recall  f1-score   support
#
#   Lungcancer       1.00      1.00      1.00        31
#       Normal       1.00      1.00      1.00        28
# Tuberculosis       1.00      1.00      1.00        31
#
#     accuracy                           1.00        90
#    macro avg       1.00      1.00      1.00        90
# weighted avg       1.00      1.00      1.00        90
#
#               precision    recall  f1-score   support
#
#   Lungcancer       1.00      0.81      0.90       150
#       Normal       0.99      0.89      0.94       150
# Tuberculosis       0.78      1.00      0.88       150
#
#     accuracy                           0.90       450
#    macro avg       0.92      0.90      0.90       450
# weighted avg       0.92      0.90      0.90       450

# %% [markdown]
# #### 8 soft pre bi sgd

# %%
BS = 8
filepath = "Kmodel8_soft_pre_bi_sgd.h5"                  ##

train_img_Incep = []
for ImageName in tqdm(data_train3['ImageName']):              
    image_path = All_3class_dir +'/' + ImageName                  
    img = cv2.imread(image_path)                                          
    img = cv2.resize(img, (299, 299))                                      
    train_img_Incep.append(img)
data_Incep = np.array(train_img_Incep, dtype="float32") / 255.0

labels_Incep = np.array(data_train3[['NameType']] )        
labels_Incep.shape = (len(labels_Incep),) 
le_Incep = LabelEncoder()                                                                     
labels_Incep = le_Incep.fit_transform(labels_Incep)                                         
labels_Incep = to_categorical(labels_Incep, num_classes=3)                   

aug = ImageDataGenerator( rotation_range=15,	width_shift_range=0.1, 	height_shift_range=0.1,
		shear_range=0.15, 	horizontal_flip=True, 	fill_mode="nearest")
                                                                                                           ## 
callback = EarlyStopping( monitor= "val_accuracy",    patience=15,       mode="max" , baseline=1.0)

# checkpoint = ModelCheckpoint(filepath, monitor='val_accuracy', verbose=1,   save_best_only=True, mode='max')
                                                                                                            ##
reduce_lr = ReduceLROnPlateau(monitor='val_accuracy', factor=0.5,   patience=6,     verbose=1, mode='max', min_lr=0.00001)
# Out:
# 100%|██████████| 450/450 [00:05<00:00, 87.86it/s]

# %%
base_model_Incep = tf.keras.applications.InceptionV3(input_shape=(299, 299, 3), include_top=False, weights="imagenet")
len(base_model_Incep.layers)

base_model_Incep.trainable = True
for layer in base_model_Incep.layers[:100]:    #fix w & bias in layer 0-100
    layer.trainable = False


#Add custom head
average_pooling_layer = tf.keras.layers.GlobalAveragePooling2D()(base_model_Incep.output)
prediction_layer = tf.keras.layers.Dense(units=3, activation="softmax")(average_pooling_layer)   # unit 3
model_Incep = tf.keras.models.Model(inputs=base_model_Incep.input, outputs=prediction_layer)

model_Incep.compile(optimizer=SGD(learning_rate=0.0001), loss="binary_crossentropy", metrics=["accuracy"])


### K-fold
kf_Incep = KFold(5, shuffle=True, random_state=40) 

oos_y = []
oos_pred = []
fold = 0

for train, test in kf_Incep.split(data_Incep):
    fold+=1   
    print(f"Fold #{fold}")

    filename = f" Kmodel8_soft_pre_bi_sgd{fold}.h5 "
    checkpoint = ModelCheckpoint(filename, monitor='val_accuracy', verbose=1,   save_best_only=True, mode='max')
        
    x_train_Incep = data_Incep[train]
    y_train_Incep = labels_Incep[train]
    x_test_Incep = data_Incep[test]
    y_test_Incep = labels_Incep[test]

    H_Incep = model_Incep.fit( x=aug.flow(x_train_Incep, y_train_Incep, batch_size=BS),
	                                            validation_data=(x_test_Incep, y_test_Incep),
	                                            steps_per_epoch=len(x_train_Incep) // BS,
	                                            epochs=100,  callbacks = [callback,checkpoint,reduce_lr])

    pred_Incep = model_Incep.predict(x_test_Incep)
    
    oos_y.append(y_test_Incep)
    oos_pred.append(pred_Incep)  
    print(classification_report(y_test_Incep.argmax(axis=1),	                #แสดง report ค่า acc, recall, ...
                                        pred_Incep.argmax(axis=1),  
                                        target_names=le_Incep.classes_))
    
oos_y = np.concatenate(oos_y)
oos_pred = np.concatenate(oos_pred)
print(classification_report(oos_y.argmax(axis=1), oos_pred.argmax(axis=1),  target_names=le_Incep.classes_))

# %% [markdown]
# #### 8 soft pre cate

# %%
BS = 8
filepath = "Kmodel8_soft_pre_cate.h5"                  ##

train_img_Incep = []
for ImageName in tqdm(data_train3['ImageName']):              
    image_path = All_3class_dir +'/' + ImageName                  
    img = cv2.imread(image_path)                                          
    img = cv2.resize(img, (299, 299))                                      
    train_img_Incep.append(img)
data_Incep = np.array(train_img_Incep, dtype="float32") / 255.0

labels_Incep = np.array(data_train3[['NameType']] )        
labels_Incep.shape = (len(labels_Incep),) 
le_Incep = LabelEncoder()                                                                     
labels_Incep = le_Incep.fit_transform(labels_Incep)                                         
labels_Incep = to_categorical(labels_Incep, num_classes=3)                   

aug = ImageDataGenerator( rotation_range=15,	width_shift_range=0.1, 	height_shift_range=0.1,
		shear_range=0.15, 	horizontal_flip=True, 	fill_mode="nearest")
                                                                                                           ## 
callback = EarlyStopping( monitor= "val_accuracy",    patience=15,       mode="max" , baseline=1.0)

# checkpoint = ModelCheckpoint(filepath, monitor='val_accuracy', verbose=1,   save_best_only=True, mode='max')
                                                                                                            ##
reduce_lr = ReduceLROnPlateau(monitor='val_accuracy', factor=0.5,   patience=6,     verbose=1, mode='max', min_lr=0.00001)

# %%
base_model_Incep = tf.keras.applications.InceptionV3(input_shape=(299, 299, 3), include_top=False, weights="imagenet")
len(base_model_Incep.layers)

base_model_Incep.trainable = True
for layer in base_model_Incep.layers[:100]:    #fix w & bias in layer 0-100
    layer.trainable = False


#Add custom head
average_pooling_layer = tf.keras.layers.GlobalAveragePooling2D()(base_model_Incep.output)
prediction_layer = tf.keras.layers.Dense(units=3, activation="softmax")(average_pooling_layer)   # unit 3
model_Incep = tf.keras.models.Model(inputs=base_model_Incep.input, outputs=prediction_layer)

model_Incep.compile(optimizer=RMSprop(learning_rate=0.0001), loss="categorical_crossentropy", metrics=["accuracy"])


### K-fold
kf_Incep = KFold(5, shuffle=True, random_state=40) 

oos_y = []
oos_pred = []
fold = 0

for train, test in kf_Incep.split(data_Incep):
    fold+=1   
    print(f"Fold #{fold}")

    filename = f" Kmodel8_soft_pre_cate{fold}.h5 "
    checkpoint = ModelCheckpoint(filename, monitor='val_accuracy', verbose=1,   save_best_only=True, mode='max')
        
    x_train_Incep = data_Incep[train]
    y_train_Incep = labels_Incep[train]
    x_test_Incep = data_Incep[test]
    y_test_Incep = labels_Incep[test]

    H_Incep = model_Incep.fit( x=aug.flow(x_train_Incep, y_train_Incep, batch_size=BS),
	                                            validation_data=(x_test_Incep, y_test_Incep),
	                                            steps_per_epoch=len(x_train_Incep) // BS,
	                                            epochs=100,  callbacks = [callback,checkpoint,reduce_lr])

    pred_Incep = model_Incep.predict(x_test_Incep)
    
    oos_y.append(y_test_Incep)
    oos_pred.append(pred_Incep)  
    print(classification_report(y_test_Incep.argmax(axis=1),	                #แสดง report ค่า acc, recall, ...
                                        pred_Incep.argmax(axis=1),  
                                        target_names=le_Incep.classes_))
    
oos_y = np.concatenate(oos_y)
oos_pred = np.concatenate(oos_pred)
print(classification_report(oos_y.argmax(axis=1), oos_pred.argmax(axis=1),  target_names=le_Incep.classes_))

# %% [markdown]
# #### 8 soft pre cate adam

# %%
BS = 8
filepath = "Kmodel8_soft_pre_cate_adam.h5"                  ##

train_img_Incep = []
for ImageName in tqdm(data_train3['ImageName']):              
    image_path = All_3class_dir +'/' + ImageName                  
    img = cv2.imread(image_path)                                          
    img = cv2.resize(img, (299, 299))                                      
    train_img_Incep.append(img)
data_Incep = np.array(train_img_Incep, dtype="float32") / 255.0

labels_Incep = np.array(data_train3[['NameType']] )        
labels_Incep.shape = (len(labels_Incep),) 
le_Incep = LabelEncoder()                                                                     
labels_Incep = le_Incep.fit_transform(labels_Incep)                                         
labels_Incep = to_categorical(labels_Incep, num_classes=3)                   

aug = ImageDataGenerator( rotation_range=15,	width_shift_range=0.1, 	height_shift_range=0.1,
		shear_range=0.15, 	horizontal_flip=True, 	fill_mode="nearest")
                                                                                                           ## 
callback = EarlyStopping( monitor= "val_accuracy",    patience=15,       mode="max" , baseline=1.0)

# checkpoint = ModelCheckpoint(filepath, monitor='val_accuracy', verbose=1,   save_best_only=True, mode='max')
                                                                                                            ##
reduce_lr = ReduceLROnPlateau(monitor='val_accuracy', factor=0.5,   patience=6,     verbose=1, mode='max', min_lr=0.00001)

# %%
base_model_Incep = tf.keras.applications.InceptionV3(input_shape=(299, 299, 3), include_top=False, weights="imagenet")
len(base_model_Incep.layers)

base_model_Incep.trainable = True
for layer in base_model_Incep.layers[:100]:    #fix w & bias in layer 0-100
    layer.trainable = False


#Add custom head
average_pooling_layer = tf.keras.layers.GlobalAveragePooling2D()(base_model_Incep.output)
prediction_layer = tf.keras.layers.Dense(units=3, activation="softmax")(average_pooling_layer)   # unit 3
model_Incep = tf.keras.models.Model(inputs=base_model_Incep.input, outputs=prediction_layer)

model_Incep.compile(optimizer=Adam(learning_rate=0.0001), loss="categorical_crossentropy", metrics=["accuracy"])

### K-fold
kf_Incep = KFold(5, shuffle=True, random_state=40) 

oos_y = []
oos_pred = []
fold = 0

for train, test in kf_Incep.split(data_Incep):
    fold+=1   
    print(f"Fold #{fold}")

    filename = f" Kmodel8_soft_pre_cate_adam{fold}.h5 "
    checkpoint = ModelCheckpoint(filename, monitor='val_accuracy', verbose=1,   save_best_only=True, mode='max')
        
    x_train_Incep = data_Incep[train]
    y_train_Incep = labels_Incep[train]
    x_test_Incep = data_Incep[test]
    y_test_Incep = labels_Incep[test]

    H_Incep = model_Incep.fit( x=aug.flow(x_train_Incep, y_train_Incep, batch_size=BS),
	                                            validation_data=(x_test_Incep, y_test_Incep),
	                                            steps_per_epoch=len(x_train_Incep) // BS,
	                                            epochs=100,  callbacks = [callback,checkpoint,reduce_lr])

    pred_Incep = model_Incep.predict(x_test_Incep)
    
    oos_y.append(y_test_Incep)
    oos_pred.append(pred_Incep)  
    print(classification_report(y_test_Incep.argmax(axis=1),	                #แสดง report ค่า acc, recall, ...
                                        pred_Incep.argmax(axis=1),  
                                        target_names=le_Incep.classes_))
    
oos_y = np.concatenate(oos_y)
oos_pred = np.concatenate(oos_pred)
print(classification_report(oos_y.argmax(axis=1), oos_pred.argmax(axis=1),  target_names=le_Incep.classes_))

# %% [markdown]
# #### 8 soft pre cate sgd

# %%
BS = 8
filepath = "Kmodel8_soft_pre_cate_sgd.h5"                  ##

train_img_Incep = []
for ImageName in tqdm(data_train3['ImageName']):              
    image_path = All_3class_dir +'/' + ImageName                  
    img = cv2.imread(image_path)                                          
    img = cv2.resize(img, (299, 299))                                      
    train_img_Incep.append(img)
data_Incep = np.array(train_img_Incep, dtype="float32") / 255.0

labels_Incep = np.array(data_train3[['NameType']] )        
labels_Incep.shape = (len(labels_Incep),) 
le_Incep = LabelEncoder()                                                                     
labels_Incep = le_Incep.fit_transform(labels_Incep)                                         
labels_Incep = to_categorical(labels_Incep, num_classes=3)                   

aug = ImageDataGenerator( rotation_range=15,	width_shift_range=0.1, 	height_shift_range=0.1,
		shear_range=0.15, 	horizontal_flip=True, 	fill_mode="nearest")
                                                                                                           ## 
callback = EarlyStopping( monitor= "val_accuracy",    patience=15,       mode="max" , baseline=1.0)

# checkpoint = ModelCheckpoint(filepath, monitor='val_accuracy', verbose=1,   save_best_only=True, mode='max')
                                                                                                            ##
reduce_lr = ReduceLROnPlateau(monitor='val_accuracy', factor=0.5,   patience=6,     verbose=1, mode='max', min_lr=0.00001)

# %%
base_model_Incep = tf.keras.applications.InceptionV3(input_shape=(299, 299, 3), include_top=False, weights="imagenet")
len(base_model_Incep.layers)

base_model_Incep.trainable = True
for layer in base_model_Incep.layers[:100]:    #fix w & bias in layer 0-100
    layer.trainable = False


#Add custom head
average_pooling_layer = tf.keras.layers.GlobalAveragePooling2D()(base_model_Incep.output)
prediction_layer = tf.keras.layers.Dense(units=3, activation="softmax")(average_pooling_layer)   # unit 3
model_Incep = tf.keras.models.Model(inputs=base_model_Incep.input, outputs=prediction_layer)

model_Incep.compile(optimizer=SGD(learning_rate=0.0001), loss="categorical_crossentropy", metrics=["accuracy"])

### K-fold
kf_Incep = KFold(5, shuffle=True, random_state=40) 

oos_y = []
oos_pred = []
fold = 0

for train, test in kf_Incep.split(data_Incep):
    fold+=1   
    print(f"Fold #{fold}")

    filename = f" Kmodel8_soft_pre_cate_sgd{fold}.h5 "
    checkpoint = ModelCheckpoint(filename, monitor='val_accuracy', verbose=1,   save_best_only=True, mode='max')
        
    x_train_Incep = data_Incep[train]
    y_train_Incep = labels_Incep[train]
    x_test_Incep = data_Incep[test]
    y_test_Incep = labels_Incep[test]

    H_Incep = model_Incep.fit( x=aug.flow(x_train_Incep, y_train_Incep, batch_size=BS),
	                                            validation_data=(x_test_Incep, y_test_Incep),
	                                            steps_per_epoch=len(x_train_Incep) // BS,
	                                            epochs=100,  callbacks = [callback,checkpoint,reduce_lr])

    pred_Incep = model_Incep.predict(x_test_Incep)
    
    oos_y.append(y_test_Incep)
    oos_pred.append(pred_Incep)  
    print(classification_report(y_test_Incep.argmax(axis=1),	                #แสดง report ค่า acc, recall, ...
                                        pred_Incep.argmax(axis=1),  
                                        target_names=le_Incep.classes_))
    
oos_y = np.concatenate(oos_y)
oos_pred = np.concatenate(oos_pred)
print(classification_report(oos_y.argmax(axis=1), oos_pred.argmax(axis=1),  target_names=le_Incep.classes_))

# %% [markdown]
# ### 16

# %% [markdown]
# #### 16  soft pre bi

# %%
BS = 16
filepath = "Kmodel16_soft_pre_bi.h5"                  ##

train_img_Incep = []
for ImageName in tqdm(data_train3['ImageName']):              
    image_path = All_3class_dir +'/' + ImageName                  
    img = cv2.imread(image_path)                                          
    img = cv2.resize(img, (299, 299))                                      
    train_img_Incep.append(img)
data_Incep = np.array(train_img_Incep, dtype="float32") / 255.0

labels_Incep = np.array(data_train3[['NameType']] )        
labels_Incep.shape = (len(labels_Incep),) 
le_Incep = LabelEncoder()                                                                     
labels_Incep = le_Incep.fit_transform(labels_Incep)                                         
labels_Incep = to_categorical(labels_Incep, num_classes=3)                   

aug = ImageDataGenerator( rotation_range=15,	width_shift_range=0.1, 	height_shift_range=0.1,
		shear_range=0.15, 	horizontal_flip=True, 	fill_mode="nearest")
                                                                                                           ## 
callback = EarlyStopping( monitor= "val_accuracy",    patience=15,       mode="max" , baseline=1.0)

# checkpoint = ModelCheckpoint(filepath, monitor='val_accuracy', verbose=1,   save_best_only=True, mode='max')
                                                                                                            ##
reduce_lr = ReduceLROnPlateau(monitor='val_accuracy', factor=0.5,   patience=6,     verbose=1, mode='max', min_lr=0.00001)

# %%
base_model_Incep = tf.keras.applications.InceptionV3(input_shape=(299, 299, 3), include_top=False, weights="imagenet")
len(base_model_Incep.layers)

base_model_Incep.trainable = True
for layer in base_model_Incep.layers[:100]:    #fix w & bias in layer 0-100
    layer.trainable = False


#Add custom head
average_pooling_layer = tf.keras.layers.GlobalAveragePooling2D()(base_model_Incep.output)
prediction_layer = tf.keras.layers.Dense(units=3, activation="softmax")(average_pooling_layer)   # unit 3
model_Incep = tf.keras.models.Model(inputs=base_model_Incep.input, outputs=prediction_layer)

model_Incep.compile(optimizer=RMSprop(learning_rate=0.0001), loss="binary_crossentropy", metrics=["accuracy"])


### K-fold
kf_Incep = KFold(5, shuffle=True, random_state=40) 

oos_y = []
oos_pred = []
fold = 0

for train, test in kf_Incep.split(data_Incep):
    fold+=1   
    print(f"Fold #{fold}")

    filename = f" Kmodel16_soft_pre_bi{fold}.h5 "
    checkpoint = ModelCheckpoint(filename, monitor='val_accuracy', verbose=1,   save_best_only=True, mode='max')
        
    x_train_Incep = data_Incep[train]
    y_train_Incep = labels_Incep[train]
    x_test_Incep = data_Incep[test]
    y_test_Incep = labels_Incep[test]

    H_Incep = model_Incep.fit( x=aug.flow(x_train_Incep, y_train_Incep, batch_size=BS),
	                                            validation_data=(x_test_Incep, y_test_Incep),
	                                            steps_per_epoch=len(x_train_Incep) // BS,
	                                            epochs=100,  callbacks = [callback,checkpoint,reduce_lr])

    pred_Incep = model_Incep.predict(x_test_Incep)
    
    oos_y.append(y_test_Incep)
    oos_pred.append(pred_Incep)  
    print(classification_report(y_test_Incep.argmax(axis=1),	                #แสดง report ค่า acc, recall, ...
                                        pred_Incep.argmax(axis=1),  
                                        target_names=le_Incep.classes_))
    
oos_y = np.concatenate(oos_y)
oos_pred = np.concatenate(oos_pred)
print(classification_report(oos_y.argmax(axis=1), oos_pred.argmax(axis=1),  target_names=le_Incep.classes_))

# %% [markdown]
# #### 16 soft pre bi adam

# %%
BS = 16
filepath = "Kmodel16_soft_pre_bi_adam.h5"                  ##

train_img_Incep = []
for ImageName in tqdm(data_train3['ImageName']):              
    image_path = All_3class_dir +'/' + ImageName                  
    img = cv2.imread(image_path)                                          
    img = cv2.resize(img, (299, 299))                                      
    train_img_Incep.append(img)
data_Incep = np.array(train_img_Incep, dtype="float32") / 255.0

labels_Incep = np.array(data_train3[['NameType']] )        
labels_Incep.shape = (len(labels_Incep),) 
le_Incep = LabelEncoder()                                                                     
labels_Incep = le_Incep.fit_transform(labels_Incep)                                         
labels_Incep = to_categorical(labels_Incep, num_classes=3)                   

aug = ImageDataGenerator( rotation_range=15,	width_shift_range=0.1, 	height_shift_range=0.1,
		shear_range=0.15, 	horizontal_flip=True, 	fill_mode="nearest")
                                                                                                           ## 
callback = EarlyStopping( monitor= "val_accuracy",    patience=15,       mode="max" , baseline=1.0)

# checkpoint = ModelCheckpoint(filepath, monitor='val_accuracy', verbose=1,   save_best_only=True, mode='max')
                                                                                                            ##
reduce_lr = ReduceLROnPlateau(monitor='val_accuracy', factor=0.5,   patience=6,     verbose=1, mode='max', min_lr=0.00001)

# %%
base_model_Incep = tf.keras.applications.InceptionV3(input_shape=(299, 299, 3), include_top=False, weights="imagenet")
len(base_model_Incep.layers)

base_model_Incep.trainable = True
for layer in base_model_Incep.layers[:100]:    #fix w & bias in layer 0-100
    layer.trainable = False


#Add custom head
average_pooling_layer = tf.keras.layers.GlobalAveragePooling2D()(base_model_Incep.output)
prediction_layer = tf.keras.layers.Dense(units=3, activation="softmax")(average_pooling_layer)   # unit 3
model_Incep = tf.keras.models.Model(inputs=base_model_Incep.input, outputs=prediction_layer)

model_Incep.compile(optimizer=Adam(learning_rate=0.0001), loss="binary_crossentropy", metrics=["accuracy"])


### K-fold
kf_Incep = KFold(5, shuffle=True, random_state=40) 

oos_y = []
oos_pred = []
fold = 0

for train, test in kf_Incep.split(data_Incep):
    fold+=1   
    print(f"Fold #{fold}")

    filename = f" Kmodel16_soft_pre_bi_adam{fold}.h5 "
    checkpoint = ModelCheckpoint(filename, monitor='val_accuracy', verbose=1,   save_best_only=True, mode='max')
        
    x_train_Incep = data_Incep[train]
    y_train_Incep = labels_Incep[train]
    x_test_Incep = data_Incep[test]
    y_test_Incep = labels_Incep[test]

    H_Incep = model_Incep.fit( x=aug.flow(x_train_Incep, y_train_Incep, batch_size=BS),
	                                            validation_data=(x_test_Incep, y_test_Incep),
	                                            steps_per_epoch=len(x_train_Incep) // BS,
	                                            epochs=100,  callbacks = [callback,checkpoint,reduce_lr])

    pred_Incep = model_Incep.predict(x_test_Incep)
    
    oos_y.append(y_test_Incep)
    oos_pred.append(pred_Incep)  
    print(classification_report(y_test_Incep.argmax(axis=1),	                #แสดง report ค่า acc, recall, ...
                                        pred_Incep.argmax(axis=1),  
                                        target_names=le_Incep.classes_))
    
oos_y = np.concatenate(oos_y)
oos_pred = np.concatenate(oos_pred)
print(classification_report(oos_y.argmax(axis=1), oos_pred.argmax(axis=1),  target_names=le_Incep.classes_))

# %% [markdown]
# #### 16 soft pre bi sgd

# %%
BS = 16
filepath = "Kmodel16_soft_pre_bi_sgd.h5"                  ##

train_img_Incep = []
for ImageName in tqdm(data_train3['ImageName']):              
    image_path = All_3class_dir +'/' + ImageName                  
    img = cv2.imread(image_path)                                          
    img = cv2.resize(img, (299, 299))                                      
    train_img_Incep.append(img)
data_Incep = np.array(train_img_Incep, dtype="float32") / 255.0

labels_Incep = np.array(data_train3[['NameType']] )        
labels_Incep.shape = (len(labels_Incep),) 
le_Incep = LabelEncoder()                                                                     
labels_Incep = le_Incep.fit_transform(labels_Incep)                                         
labels_Incep = to_categorical(labels_Incep, num_classes=3)                   

aug = ImageDataGenerator( rotation_range=15,	width_shift_range=0.1, 	height_shift_range=0.1,
		shear_range=0.15, 	horizontal_flip=True, 	fill_mode="nearest")
                                                                                                           ## 
callback = EarlyStopping( monitor= "val_accuracy",    patience=15,       mode="max" , baseline=1.0)

# checkpoint = ModelCheckpoint(filepath, monitor='val_accuracy', verbose=1,   save_best_only=True, mode='max')
                                                                                                            ##
reduce_lr = ReduceLROnPlateau(monitor='val_accuracy', factor=0.5,   patience=6,     verbose=1, mode='max', min_lr=0.00001)

# %%
base_model_Incep = tf.keras.applications.InceptionV3(input_shape=(299, 299, 3), include_top=False, weights="imagenet")
len(base_model_Incep.layers)

base_model_Incep.trainable = True
for layer in base_model_Incep.layers[:100]:    #fix w & bias in layer 0-100
    layer.trainable = False


#Add custom head
average_pooling_layer = tf.keras.layers.GlobalAveragePooling2D()(base_model_Incep.output)
prediction_layer = tf.keras.layers.Dense(units=3, activation="softmax")(average_pooling_layer)   # unit 3
model_Incep = tf.keras.models.Model(inputs=base_model_Incep.input, outputs=prediction_layer)

model_Incep.compile(optimizer=SGD(learning_rate=0.0001), loss="binary_crossentropy", metrics=["accuracy"])


### K-fold
kf_Incep = KFold(5, shuffle=True, random_state=40) 

oos_y = []
oos_pred = []
fold = 0

for train, test in kf_Incep.split(data_Incep):
    fold+=1   
    print(f"Fold #{fold}")

    filename = f" Kmodel16_soft_pre_bi_sgd{fold}.h5 "
    checkpoint = ModelCheckpoint(filename, monitor='val_accuracy', verbose=1,   save_best_only=True, mode='max')
        
    x_train_Incep = data_Incep[train]
    y_train_Incep = labels_Incep[train]
    x_test_Incep = data_Incep[test]
    y_test_Incep = labels_Incep[test]

    H_Incep = model_Incep.fit( x=aug.flow(x_train_Incep, y_train_Incep, batch_size=BS),
	                                            validation_data=(x_test_Incep, y_test_Incep),
	                                            steps_per_epoch=len(x_train_Incep) // BS,
	                                            epochs=100,  callbacks = [callback,checkpoint,reduce_lr])

    pred_Incep = model_Incep.predict(x_test_Incep)
    
    oos_y.append(y_test_Incep)
    oos_pred.append(pred_Incep)  
    print(classification_report(y_test_Incep.argmax(axis=1),	                #แสดง report ค่า acc, recall, ...
                                        pred_Incep.argmax(axis=1),  
                                        target_names=le_Incep.classes_))
    
oos_y = np.concatenate(oos_y)
oos_pred = np.concatenate(oos_pred)
print(classification_report(oos_y.argmax(axis=1), oos_pred.argmax(axis=1),  target_names=le_Incep.classes_))

# %% [markdown]
# #### 16 soft pre cate

# %%
BS = 16
filepath = "Kmodel16_soft_pre_cate.h5"                  ##

train_img_Incep = []
for ImageName in tqdm(data_train3['ImageName']):              
    image_path = All_3class_dir +'/' + ImageName                  
    img = cv2.imread(image_path)                                          
    img = cv2.resize(img, (299, 299))                                      
    train_img_Incep.append(img)
data_Incep = np.array(train_img_Incep, dtype="float32") / 255.0

labels_Incep = np.array(data_train3[['NameType']] )        
labels_Incep.shape = (len(labels_Incep),) 
le_Incep = LabelEncoder()                                                                     
labels_Incep = le_Incep.fit_transform(labels_Incep)                                         
labels_Incep = to_categorical(labels_Incep, num_classes=3)                   

aug = ImageDataGenerator( rotation_range=15,	width_shift_range=0.1, 	height_shift_range=0.1,
		shear_range=0.15, 	horizontal_flip=True, 	fill_mode="nearest")
                                                                                                           ## 
callback = EarlyStopping( monitor= "val_accuracy",    patience=15,       mode="max" , baseline=1.0)

# checkpoint = ModelCheckpoint(filepath, monitor='val_accuracy', verbose=1,   save_best_only=True, mode='max')
                                                                                                            ##
reduce_lr = ReduceLROnPlateau(monitor='val_accuracy', factor=0.5,   patience=6,     verbose=1, mode='max', min_lr=0.00001)

# %%
base_model_Incep = tf.keras.applications.InceptionV3(input_shape=(299, 299, 3), include_top=False, weights="imagenet")
len(base_model_Incep.layers)

base_model_Incep.trainable = True
for layer in base_model_Incep.layers[:100]:    #fix w & bias in layer 0-100
    layer.trainable = False


#Add custom head
average_pooling_layer = tf.keras.layers.GlobalAveragePooling2D()(base_model_Incep.output)
prediction_layer = tf.keras.layers.Dense(units=3, activation="softmax")(average_pooling_layer)   # unit 3
model_Incep = tf.keras.models.Model(inputs=base_model_Incep.input, outputs=prediction_layer)

model_Incep.compile(optimizer=RMSprop(learning_rate=0.0001), loss="categorical_crossentropy", metrics=["accuracy"])


### K-fold
kf_Incep = KFold(5, shuffle=True, random_state=40) 

oos_y = []
oos_pred = []
fold = 0

for train, test in kf_Incep.split(data_Incep):
    fold+=1   
    print(f"Fold #{fold}")

    filename = f" Kmodel16_soft_pre_cate{fold}.h5 "
    checkpoint = ModelCheckpoint(filename, monitor='val_accuracy', verbose=1,   save_best_only=True, mode='max')
        
    x_train_Incep = data_Incep[train]
    y_train_Incep = labels_Incep[train]
    x_test_Incep = data_Incep[test]
    y_test_Incep = labels_Incep[test]

    H_Incep = model_Incep.fit( x=aug.flow(x_train_Incep, y_train_Incep, batch_size=BS),
	                                            validation_data=(x_test_Incep, y_test_Incep),
	                                            steps_per_epoch=len(x_train_Incep) // BS,
	                                            epochs=100,  callbacks = [callback,checkpoint,reduce_lr])

    pred_Incep = model_Incep.predict(x_test_Incep)
    
    oos_y.append(y_test_Incep)
    oos_pred.append(pred_Incep)  
    print(classification_report(y_test_Incep.argmax(axis=1),	                #แสดง report ค่า acc, recall, ...
                                        pred_Incep.argmax(axis=1),  
                                        target_names=le_Incep.classes_))
    
oos_y = np.concatenate(oos_y)
oos_pred = np.concatenate(oos_pred)
print(classification_report(oos_y.argmax(axis=1), oos_pred.argmax(axis=1),  target_names=le_Incep.classes_))

# %% [markdown]
# ####16 soft pre cate adam

# %%
BS = 16                                                       ##
filepath = "Kmodel16_soft_pre_cate_adam.h5"                  ##

train_img_Incep = []
for ImageName in tqdm(data_train3['ImageName']):              
    image_path = All_3class_dir +'/' + ImageName                  
    img = cv2.imread(image_path)                                          
    img = cv2.resize(img, (299, 299))                                      
    train_img_Incep.append(img)
data_Incep = np.array(train_img_Incep, dtype="float32") / 255.0

labels_Incep = np.array(data_train3[['NameType']] )        
labels_Incep.shape = (len(labels_Incep),) 
le_Incep = LabelEncoder()                                                                     
labels_Incep = le_Incep.fit_transform(labels_Incep)                                         
labels_Incep = to_categorical(labels_Incep, num_classes=3)                   

aug = ImageDataGenerator( rotation_range=15,	width_shift_range=0.1, 	height_shift_range=0.1,
		shear_range=0.15, 	horizontal_flip=True, 	fill_mode="nearest")
                                                                                                           ## 
callback = EarlyStopping( monitor= "val_accuracy",    patience=15,       mode="max" , baseline=1.0)

# checkpoint = ModelCheckpoint(filepath, monitor='val_accuracy', verbose=1,   save_best_only=True, mode='max')
                                                                                                            ##
reduce_lr = ReduceLROnPlateau(monitor='val_accuracy', factor=0.5,   patience=6,     verbose=1, mode='max', min_lr=0.00001)

# %%
base_model_Incep = tf.keras.applications.InceptionV3(input_shape=(299, 299, 3), include_top=False, weights="imagenet")
len(base_model_Incep.layers)

base_model_Incep.trainable = True
for layer in base_model_Incep.layers[:100]:    #fix w & bias in layer 0-100
    layer.trainable = False


#Add custom head
average_pooling_layer = tf.keras.layers.GlobalAveragePooling2D()(base_model_Incep.output)
prediction_layer = tf.keras.layers.Dense(units=3, activation="softmax")(average_pooling_layer)   # unit 3
model_Incep = tf.keras.models.Model(inputs=base_model_Incep.input, outputs=prediction_layer)

model_Incep.compile(optimizer=Adam(learning_rate=0.0001), loss="categorical_crossentropy", metrics=["accuracy"])

### K-fold
kf_Incep = KFold(5, shuffle=True, random_state=40) 

oos_y = []
oos_pred = []
fold = 0

for train, test in kf_Incep.split(data_Incep):
    fold+=1   
    print(f"Fold #{fold}")

    filename = f" Kmodel16_soft_pre_cate_adam{fold}.h5 "
    checkpoint = ModelCheckpoint(filename, monitor='val_accuracy', verbose=1,   save_best_only=True, mode='max')
        
    x_train_Incep = data_Incep[train]
    y_train_Incep = labels_Incep[train]
    x_test_Incep = data_Incep[test]
    y_test_Incep = labels_Incep[test]

    H_Incep = model_Incep.fit( x=aug.flow(x_train_Incep, y_train_Incep, batch_size=BS),
	                                            validation_data=(x_test_Incep, y_test_Incep),
	                                            steps_per_epoch=len(x_train_Incep) // BS,
	                                            epochs=100,  callbacks = [callback,checkpoint,reduce_lr])

    pred_Incep = model_Incep.predict(x_test_Incep)
    
    oos_y.append(y_test_Incep)
    oos_pred.append(pred_Incep)  
    print(classification_report(y_test_Incep.argmax(axis=1),	                #แสดง report ค่า acc, recall, ...
                                        pred_Incep.argmax(axis=1),  
                                        target_names=le_Incep.classes_))
    
oos_y = np.concatenate(oos_y)
oos_pred = np.concatenate(oos_pred)
print(classification_report(oos_y.argmax(axis=1), oos_pred.argmax(axis=1),  target_names=le_Incep.classes_))

# %% [markdown]
# #### 16 soft pre cate sgd

# %%
BS = 16                                                       ##
filepath = "Kmodel16_soft_pre_cate_sgd.h5"                  ##

train_img_Incep = []
for ImageName in tqdm(data_train3['ImageName']):              
    image_path = All_3class_dir +'/' + ImageName                  
    img = cv2.imread(image_path)                                          
    img = cv2.resize(img, (299, 299))                                      
    train_img_Incep.append(img)
data_Incep = np.array(train_img_Incep, dtype="float32") / 255.0

labels_Incep = np.array(data_train3[['NameType']] )        
labels_Incep.shape = (len(labels_Incep),) 
le_Incep = LabelEncoder()                                                                     
labels_Incep = le_Incep.fit_transform(labels_Incep)                                         
labels_Incep = to_categorical(labels_Incep, num_classes=3)                   

aug = ImageDataGenerator( rotation_range=15,	width_shift_range=0.1, 	height_shift_range=0.1,
		shear_range=0.15, 	horizontal_flip=True, 	fill_mode="nearest")
                                                                                                           ## 
callback = EarlyStopping( monitor= "val_accuracy",    patience=15,       mode="max" , baseline=1.0)

# checkpoint = ModelCheckpoint(filepath, monitor='val_accuracy', verbose=1,   save_best_only=True, mode='max')
                                                                                                            ##
reduce_lr = ReduceLROnPlateau(monitor='val_accuracy', factor=0.5,   patience=6,     verbose=1, mode='max', min_lr=0.00001)

# %%
base_model_Incep = tf.keras.applications.InceptionV3(input_shape=(299, 299, 3), include_top=False, weights="imagenet")
len(base_model_Incep.layers)

base_model_Incep.trainable = True
for layer in base_model_Incep.layers[:100]:    #fix w & bias in layer 0-100
    layer.trainable = False


#Add custom head
average_pooling_layer = tf.keras.layers.GlobalAveragePooling2D()(base_model_Incep.output)
prediction_layer = tf.keras.layers.Dense(units=3, activation="softmax")(average_pooling_layer)   # unit 3
model_Incep = tf.keras.models.Model(inputs=base_model_Incep.input, outputs=prediction_layer)

model_Incep.compile(optimizer=SGD(learning_rate=0.0001), loss="categorical_crossentropy", metrics=["accuracy"])

### K-fold
kf_Incep = KFold(5, shuffle=True, random_state=40) 

oos_y = []
oos_pred = []
fold = 0

for train, test in kf_Incep.split(data_Incep):
    fold+=1   
    print(f"Fold #{fold}")

    filename = f" Kmodel16_soft_pre_cate_sgd{fold}.h5 "
    checkpoint = ModelCheckpoint(filename, monitor='val_accuracy', verbose=1,   save_best_only=True, mode='max')
        
    x_train_Incep = data_Incep[train]
    y_train_Incep = labels_Incep[train]
    x_test_Incep = data_Incep[test]
    y_test_Incep = labels_Incep[test]

    H_Incep = model_Incep.fit( x=aug.flow(x_train_Incep, y_train_Incep, batch_size=BS),
	                                            validation_data=(x_test_Incep, y_test_Incep),
	                                            steps_per_epoch=len(x_train_Incep) // BS,
	                                            epochs=100,  callbacks = [callback,checkpoint,reduce_lr])

    pred_Incep = model_Incep.predict(x_test_Incep)
    
    oos_y.append(y_test_Incep)
    oos_pred.append(pred_Incep)  
    print(classification_report(y_test_Incep.argmax(axis=1),	                #แสดง report ค่า acc, recall, ...
                                        pred_Incep.argmax(axis=1),  
                                        target_names=le_Incep.classes_))
    
oos_y = np.concatenate(oos_y)
oos_pred = np.concatenate(oos_pred)
print(classification_report(oos_y.argmax(axis=1), oos_pred.argmax(axis=1),  target_names=le_Incep.classes_))

# %% [markdown]
# ### 32

# %% [markdown]
# #### 32  soft pre bi

# %%
BS = 32
filepath = "Kmodel32_soft_pre_bi.h5"                  ##

train_img_Incep = []
for ImageName in tqdm(data_train3['ImageName']):              
    image_path = All_3class_dir +'/' + ImageName                  
    img = cv2.imread(image_path)                                          
    img = cv2.resize(img, (299, 299))                                      
    train_img_Incep.append(img)
data_Incep = np.array(train_img_Incep, dtype="float32") / 255.0

labels_Incep = np.array(data_train3[['NameType']] )        
labels_Incep.shape = (len(labels_Incep),) 
le_Incep = LabelEncoder()                                                                     
labels_Incep = le_Incep.fit_transform(labels_Incep)                                         
labels_Incep = to_categorical(labels_Incep, num_classes=3)                   

aug = ImageDataGenerator( rotation_range=15,	width_shift_range=0.1, 	height_shift_range=0.1,
		shear_range=0.15, 	horizontal_flip=True, 	fill_mode="nearest")
                                                                                                           ## 
callback = EarlyStopping( monitor= "val_accuracy",    patience=15,       mode="max" , baseline=1.0)

# checkpoint = ModelCheckpoint(filepath, monitor='val_accuracy', verbose=1,   save_best_only=True, mode='max')
                                                                                                            ##
reduce_lr = ReduceLROnPlateau(monitor='val_accuracy', factor=0.5,   patience=6,     verbose=1, mode='max', min_lr=0.00001)

# %%
base_model_Incep = tf.keras.applications.InceptionV3(input_shape=(299, 299, 3), include_top=False, weights="imagenet")
len(base_model_Incep.layers)

base_model_Incep.trainable = True
for layer in base_model_Incep.layers[:100]:    #fix w & bias in layer 0-100
    layer.trainable = False


#Add custom head
average_pooling_layer = tf.keras.layers.GlobalAveragePooling2D()(base_model_Incep.output)
prediction_layer = tf.keras.layers.Dense(units=3, activation="softmax")(average_pooling_layer)   # unit 3
model_Incep = tf.keras.models.Model(inputs=base_model_Incep.input, outputs=prediction_layer)

model_Incep.compile(optimizer=RMSprop(learning_rate=0.0001), loss="binary_crossentropy", metrics=["accuracy"])


### K-fold
kf_Incep = KFold(5, shuffle=True, random_state=40) 

oos_y = []
oos_pred = []
fold = 0

for train, test in kf_Incep.split(data_Incep):
    fold+=1   
    print(f"Fold #{fold}")

    filename = f" Kmodel32_soft_pre_bi{fold}.h5 "
    checkpoint = ModelCheckpoint(filename, monitor='val_accuracy', verbose=1,   save_best_only=True, mode='max')
        
    x_train_Incep = data_Incep[train]
    y_train_Incep = labels_Incep[train]
    x_test_Incep = data_Incep[test]
    y_test_Incep = labels_Incep[test]

    H_Incep = model_Incep.fit( x=aug.flow(x_train_Incep, y_train_Incep, batch_size=BS),
	                                            validation_data=(x_test_Incep, y_test_Incep),
	                                            steps_per_epoch=len(x_train_Incep) // BS,
	                                            epochs=100,  callbacks = [callback,checkpoint,reduce_lr])

    pred_Incep = model_Incep.predict(x_test_Incep)
    
    oos_y.append(y_test_Incep)
    oos_pred.append(pred_Incep)  
    print(classification_report(y_test_Incep.argmax(axis=1),	                #แสดง report ค่า acc, recall, ...
                                        pred_Incep.argmax(axis=1),  
                                        target_names=le_Incep.classes_))
    
oos_y = np.concatenate(oos_y)
oos_pred = np.concatenate(oos_pred)
print(classification_report(oos_y.argmax(axis=1), oos_pred.argmax(axis=1),  target_names=le_Incep.classes_))

# %% [markdown]
# #### 32 soft pre bi adam

# %%
BS = 32
filepath = "Kmodel32_soft_pre_bi_adam.h5"                  ##

train_img_Incep = []
for ImageName in tqdm(data_train3['ImageName']):              
    image_path = All_3class_dir +'/' + ImageName                  
    img = cv2.imread(image_path)                                          
    img = cv2.resize(img, (299, 299))                                      
    train_img_Incep.append(img)
data_Incep = np.array(train_img_Incep, dtype="float32") / 255.0

labels_Incep = np.array(data_train3[['NameType']] )        
labels_Incep.shape = (len(labels_Incep),) 
le_Incep = LabelEncoder()                                                                     
labels_Incep = le_Incep.fit_transform(labels_Incep)                                         
labels_Incep = to_categorical(labels_Incep, num_classes=3)                   

aug = ImageDataGenerator( rotation_range=15,	width_shift_range=0.1, 	height_shift_range=0.1,
		shear_range=0.15, 	horizontal_flip=True, 	fill_mode="nearest")
                                                                                                           ## 
callback = EarlyStopping( monitor= "val_accuracy",    patience=15,       mode="max" , baseline=1.0)

# checkpoint = ModelCheckpoint(filepath, monitor='val_accuracy', verbose=1,   save_best_only=True, mode='max')
                                                                                                            ##
reduce_lr = ReduceLROnPlateau(monitor='val_accuracy', factor=0.5,   patience=6,     verbose=1, mode='max', min_lr=0.00001)

# %%
base_model_Incep = tf.keras.applications.InceptionV3(input_shape=(299, 299, 3), include_top=False, weights="imagenet")
len(base_model_Incep.layers)

base_model_Incep.trainable = True
for layer in base_model_Incep.layers[:100]:    #fix w & bias in layer 0-100
    layer.trainable = False


#Add custom head
average_pooling_layer = tf.keras.layers.GlobalAveragePooling2D()(base_model_Incep.output)
prediction_layer = tf.keras.layers.Dense(units=3, activation="softmax")(average_pooling_layer)   # unit 3
model_Incep = tf.keras.models.Model(inputs=base_model_Incep.input, outputs=prediction_layer)

model_Incep.compile(optimizer=Adam(learning_rate=0.0001), loss="binary_crossentropy", metrics=["accuracy"])


### K-fold
kf_Incep = KFold(5, shuffle=True, random_state=40) 

oos_y = []
oos_pred = []
fold = 0

for train, test in kf_Incep.split(data_Incep):
    fold+=1   
    print(f"Fold #{fold}")

    filename = f" Kmodel32_soft_pre_bi_adam{fold}.h5 "
    checkpoint = ModelCheckpoint(filename, monitor='val_accuracy', verbose=1,   save_best_only=True, mode='max')
        
    x_train_Incep = data_Incep[train]
    y_train_Incep = labels_Incep[train]
    x_test_Incep = data_Incep[test]
    y_test_Incep = labels_Incep[test]

    H_Incep = model_Incep.fit( x=aug.flow(x_train_Incep, y_train_Incep, batch_size=BS),
	                                            validation_data=(x_test_Incep, y_test_Incep),
	                                            steps_per_epoch=len(x_train_Incep) // BS,
	                                            epochs=100,  callbacks = [callback,checkpoint,reduce_lr])

    pred_Incep = model_Incep.predict(x_test_Incep)
    
    oos_y.append(y_test_Incep)
    oos_pred.append(pred_Incep)  
    print(classification_report(y_test_Incep.argmax(axis=1),	                #แสดง report ค่า acc, recall, ...
                                        pred_Incep.argmax(axis=1),  
                                        target_names=le_Incep.classes_))
    
oos_y = np.concatenate(oos_y)
oos_pred = np.concatenate(oos_pred)
print(classification_report(oos_y.argmax(axis=1), oos_pred.argmax(axis=1),  target_names=le_Incep.classes_))

# %% [markdown]
# #### 32 soft pre bi sgd

# %%
BS = 32
filepath = "Kmodel32_soft_pre_bi_sgd.h5"                  ##

train_img_Incep = []
for ImageName in tqdm(data_train3['ImageName']):              
    image_path = All_3class_dir +'/' + ImageName                  
    img = cv2.imread(image_path)                                          
    img = cv2.resize(img, (299, 299))                                      
    train_img_Incep.append(img)
data_Incep = np.array(train_img_Incep, dtype="float32") / 255.0

labels_Incep = np.array(data_train3[['NameType']] )        
labels_Incep.shape = (len(labels_Incep),) 
le_Incep = LabelEncoder()                                                                     
labels_Incep = le_Incep.fit_transform(labels_Incep)                                         
labels_Incep = to_categorical(labels_Incep, num_classes=3)                   

aug = ImageDataGenerator( rotation_range=15,	width_shift_range=0.1, 	height_shift_range=0.1,
		shear_range=0.15, 	horizontal_flip=True, 	fill_mode="nearest")
                                                                                                           ## 
callback = EarlyStopping( monitor= "val_accuracy",    patience=15,       mode="max" , baseline=1.0)

# checkpoint = ModelCheckpoint(filepath, monitor='val_accuracy', verbose=1,   save_best_only=True, mode='max')
                                                                                                            ##
reduce_lr = ReduceLROnPlateau(monitor='val_accuracy', factor=0.5,   patience=6,     verbose=1, mode='max', min_lr=0.00001)

# %%
base_model_Incep = tf.keras.applications.InceptionV3(input_shape=(299, 299, 3), include_top=False, weights="imagenet")
len(base_model_Incep.layers)

base_model_Incep.trainable = True
for layer in base_model_Incep.layers[:100]:    #fix w & bias in layer 0-100
    layer.trainable = False


#Add custom head
average_pooling_layer = tf.keras.layers.GlobalAveragePooling2D()(base_model_Incep.output)
prediction_layer = tf.keras.layers.Dense(units=3, activation="softmax")(average_pooling_layer)   # unit 3
model_Incep = tf.keras.models.Model(inputs=base_model_Incep.input, outputs=prediction_layer)

model_Incep.compile(optimizer=SGD(learning_rate=0.0001), loss="binary_crossentropy", metrics=["accuracy"])


### K-fold
kf_Incep = KFold(5, shuffle=True, random_state=40) 

oos_y = []
oos_pred = []
fold = 0

for train, test in kf_Incep.split(data_Incep):
    fold+=1   
    print(f"Fold #{fold}")

    filename = f" Kmodel32_soft_pre_bi_sgd{fold}.h5 "
    checkpoint = ModelCheckpoint(filename, monitor='val_accuracy', verbose=1,   save_best_only=True, mode='max')
        
    x_train_Incep = data_Incep[train]
    y_train_Incep = labels_Incep[train]
    x_test_Incep = data_Incep[test]
    y_test_Incep = labels_Incep[test]

    H_Incep = model_Incep.fit( x=aug.flow(x_train_Incep, y_train_Incep, batch_size=BS),
	                                            validation_data=(x_test_Incep, y_test_Incep),
	                                            steps_per_epoch=len(x_train_Incep) // BS,
	                                            epochs=100,  callbacks = [callback,checkpoint,reduce_lr])

    pred_Incep = model_Incep.predict(x_test_Incep)
    
    oos_y.append(y_test_Incep)
    oos_pred.append(pred_Incep)  
    print(classification_report(y_test_Incep.argmax(axis=1),	                #แสดง report ค่า acc, recall, ...
                                        pred_Incep.argmax(axis=1),  
                                        target_names=le_Incep.classes_))
    
oos_y = np.concatenate(oos_y)
oos_pred = np.concatenate(oos_pred)
print(classification_report(oos_y.argmax(axis=1), oos_pred.argmax(axis=1),  target_names=le_Incep.classes_))

# %% [markdown]
# #### 32 soft pre cate

# %%
BS = 32
filepath = "Kmodel32_soft_pre_cate.h5"                  ##

train_img_Incep = []
for ImageName in tqdm(data_train3['ImageName']):              
    image_path = All_3class_dir +'/' + ImageName                  
    img = cv2.imread(image_path)                                          
    img = cv2.resize(img, (299, 299))                                      
    train_img_Incep.append(img)
data_Incep = np.array(train_img_Incep, dtype="float32") / 255.0

labels_Incep = np.array(data_train3[['NameType']] )        
labels_Incep.shape = (len(labels_Incep),) 
le_Incep = LabelEncoder()                                                                     
labels_Incep = le_Incep.fit_transform(labels_Incep)                                         
labels_Incep = to_categorical(labels_Incep, num_classes=3)                   

aug = ImageDataGenerator( rotation_range=15,	width_shift_range=0.1, 	height_shift_range=0.1,
		shear_range=0.15, 	horizontal_flip=True, 	fill_mode="nearest")
                                                                                                           ## 
callback = EarlyStopping( monitor= "val_accuracy",    patience=15,       mode="max" , baseline=1.0)

# checkpoint = ModelCheckpoint(filepath, monitor='val_accuracy', verbose=1,   save_best_only=True, mode='max')
                                                                                                            ##
reduce_lr = ReduceLROnPlateau(monitor='val_accuracy', factor=0.5,   patience=6,     verbose=1, mode='max', min_lr=0.00001)

# %%
base_model_Incep = tf.keras.applications.InceptionV3(input_shape=(299, 299, 3), include_top=False, weights="imagenet")
len(base_model_Incep.layers)

base_model_Incep.trainable = True
for layer in base_model_Incep.layers[:100]:    #fix w & bias in layer 0-100
    layer.trainable = False


#Add custom head
average_pooling_layer = tf.keras.layers.GlobalAveragePooling2D()(base_model_Incep.output)
prediction_layer = tf.keras.layers.Dense(units=3, activation="softmax")(average_pooling_layer)   # unit 3
model_Incep = tf.keras.models.Model(inputs=base_model_Incep.input, outputs=prediction_layer)

model_Incep.compile(optimizer=RMSprop(learning_rate=0.0001), loss="categorical_crossentropy", metrics=["accuracy"])


### K-fold
kf_Incep = KFold(5, shuffle=True, random_state=40) 

oos_y = []
oos_pred = []
fold = 0

for train, test in kf_Incep.split(data_Incep):
    fold+=1   
    print(f"Fold #{fold}")

    filename = f" Kmodel32_soft_pre_cate{fold}.h5 "
    checkpoint = ModelCheckpoint(filename, monitor='val_accuracy', verbose=1,   save_best_only=True, mode='max')
        
    x_train_Incep = data_Incep[train]
    y_train_Incep = labels_Incep[train]
    x_test_Incep = data_Incep[test]
    y_test_Incep = labels_Incep[test]

    H_Incep = model_Incep.fit( x=aug.flow(x_train_Incep, y_train_Incep, batch_size=BS),
	                                            validation_data=(x_test_Incep, y_test_Incep),
	                                            steps_per_epoch=len(x_train_Incep) // BS,
	                                            epochs=100,  callbacks = [callback,checkpoint,reduce_lr])

    pred_Incep = model_Incep.predict(x_test_Incep)
    
    oos_y.append(y_test_Incep)
    oos_pred.append(pred_Incep)  
    print(classification_report(y_test_Incep.argmax(axis=1),	                #แสดง report ค่า acc, recall, ...
                                        pred_Incep.argmax(axis=1),  
                                        target_names=le_Incep.classes_))
    
oos_y = np.concatenate(oos_y)
oos_pred = np.concatenate(oos_pred)
print(classification_report(oos_y.argmax(axis=1), oos_pred.argmax(axis=1),  target_names=le_Incep.classes_))

# %% [markdown]
# #### 32 soft pre cate adam

# %%
BS = 32
filepath = "Kmodel32_soft_pre_cate_adam.h5"                  ##

train_img_Incep = []
for ImageName in tqdm(data_train3['ImageName']):              
    image_path = All_3class_dir +'/' + ImageName                  
    img = cv2.imread(image_path)                                          
    img = cv2.resize(img, (299, 299))                                      
    train_img_Incep.append(img)
data_Incep = np.array(train_img_Incep, dtype="float32") / 255.0

labels_Incep = np.array(data_train3[['NameType']] )        
labels_Incep.shape = (len(labels_Incep),) 
le_Incep = LabelEncoder()                                                                     
labels_Incep = le_Incep.fit_transform(labels_Incep)                                         
labels_Incep = to_categorical(labels_Incep, num_classes=3)                   

aug = ImageDataGenerator( rotation_range=15,	width_shift_range=0.1, 	height_shift_range=0.1,
		shear_range=0.15, 	horizontal_flip=True, 	fill_mode="nearest")
                                                                                                           ## 
callback = EarlyStopping( monitor= "val_accuracy",    patience=15,       mode="max" , baseline=1.0)

# checkpoint = ModelCheckpoint(filepath, monitor='val_accuracy', verbose=1,   save_best_only=True, mode='max')
                                                                                                            ##
reduce_lr = ReduceLROnPlateau(monitor='val_accuracy', factor=0.5,   patience=6,     verbose=1, mode='max', min_lr=0.00001)

# %%
base_model_Incep = tf.keras.applications.InceptionV3(input_shape=(299, 299, 3), include_top=False, weights="imagenet")
len(base_model_Incep.layers)

base_model_Incep.trainable = True
for layer in base_model_Incep.layers[:100]:    #fix w & bias in layer 0-100
    layer.trainable = False


#Add custom head
average_pooling_layer = tf.keras.layers.GlobalAveragePooling2D()(base_model_Incep.output)
prediction_layer = tf.keras.layers.Dense(units=3, activation="softmax")(average_pooling_layer)   # unit 3
model_Incep = tf.keras.models.Model(inputs=base_model_Incep.input, outputs=prediction_layer)

model_Incep.compile(optimizer=Adam(learning_rate=0.0001), loss="categorical_crossentropy", metrics=["accuracy"])

### K-fold
kf_Incep = KFold(5, shuffle=True, random_state=40) 

oos_y = []
oos_pred = []
fold = 0

for train, test in kf_Incep.split(data_Incep):
    fold+=1   
    print(f"Fold #{fold}")

    filename = f" Kmodel32_soft_pre_cate_adam{fold}.h5 "
    checkpoint = ModelCheckpoint(filename, monitor='val_accuracy', verbose=1,   save_best_only=True, mode='max')
        
    x_train_Incep = data_Incep[train]
    y_train_Incep = labels_Incep[train]
    x_test_Incep = data_Incep[test]
    y_test_Incep = labels_Incep[test]

    H_Incep = model_Incep.fit( x=aug.flow(x_train_Incep, y_train_Incep, batch_size=BS),
	                                            validation_data=(x_test_Incep, y_test_Incep),
	                                            steps_per_epoch=len(x_train_Incep) // BS,
	                                            epochs=100,  callbacks = [callback,checkpoint,reduce_lr])

    pred_Incep = model_Incep.predict(x_test_Incep)
    
    oos_y.append(y_test_Incep)
    oos_pred.append(pred_Incep)  
    print(classification_report(y_test_Incep.argmax(axis=1),	                #แสดง report ค่า acc, recall, ...
                                        pred_Incep.argmax(axis=1),  
                                        target_names=le_Incep.classes_))
    
oos_y = np.concatenate(oos_y)
oos_pred = np.concatenate(oos_pred)
print(classification_report(oos_y.argmax(axis=1), oos_pred.argmax(axis=1),  target_names=le_Incep.classes_))

# %% [markdown]
# #### 32 soft pre cate sgd

# %%
BS = 32
filepath = "Kmodel32_soft_pre_cate_sgd.h5"                  ##

train_img_Incep = []
for ImageName in tqdm(data_train3['ImageName']):              
    image_path = All_3class_dir +'/' + ImageName                  
    img = cv2.imread(image_path)                                          
    img = cv2.resize(img, (299, 299))                                      
    train_img_Incep.append(img)
data_Incep = np.array(train_img_Incep, dtype="float32") / 255.0

labels_Incep = np.array(data_train3[['NameType']] )        
labels_Incep.shape = (len(labels_Incep),) 
le_Incep = LabelEncoder()                                                                     
labels_Incep = le_Incep.fit_transform(labels_Incep)                                         
labels_Incep = to_categorical(labels_Incep, num_classes=3)                   

aug = ImageDataGenerator( rotation_range=15,	width_shift_range=0.1, 	height_shift_range=0.1,
		shear_range=0.15, 	horizontal_flip=True, 	fill_mode="nearest")
                                                                                                           ## 
callback = EarlyStopping( monitor= "val_accuracy",    patience=15,       mode="max" , baseline=1.0)

# checkpoint = ModelCheckpoint(filepath, monitor='val_accuracy', verbose=1,   save_best_only=True, mode='max')
                                                                                                            ##
reduce_lr = ReduceLROnPlateau(monitor='val_accuracy', factor=0.5,   patience=6,     verbose=1, mode='max', min_lr=0.00001)

# %%
base_model_Incep = tf.keras.applications.InceptionV3(input_shape=(299, 299, 3), include_top=False, weights="imagenet")
len(base_model_Incep.layers)

base_model_Incep.trainable = True
for layer in base_model_Incep.layers[:100]:    #fix w & bias in layer 0-100
    layer.trainable = False


#Add custom head
average_pooling_layer = tf.keras.layers.GlobalAveragePooling2D()(base_model_Incep.output)
prediction_layer = tf.keras.layers.Dense(units=3, activation="softmax")(average_pooling_layer)   # unit 3
model_Incep = tf.keras.models.Model(inputs=base_model_Incep.input, outputs=prediction_layer)

model_Incep.compile(optimizer=SGD(learning_rate=0.0001), loss="categorical_crossentropy", metrics=["accuracy"])

### K-fold
kf_Incep = KFold(5, shuffle=True, random_state=40) 

oos_y = []
oos_pred = []
fold = 0

for train, test in kf_Incep.split(data_Incep):
    fold+=1   
    print(f"Fold #{fold}")

    filename = f" Kmodel32_soft_pre_cate_sgd{fold}.h5 "
    checkpoint = ModelCheckpoint(filename, monitor='val_accuracy', verbose=1,   save_best_only=True, mode='max')
        
    x_train_Incep = data_Incep[train]
    y_train_Incep = labels_Incep[train]
    x_test_Incep = data_Incep[test]
    y_test_Incep = labels_Incep[test]

    H_Incep = model_Incep.fit( x=aug.flow(x_train_Incep, y_train_Incep, batch_size=BS),
	                                            validation_data=(x_test_Incep, y_test_Incep),
	                                            steps_per_epoch=len(x_train_Incep) // BS,
	                                            epochs=100,  callbacks = [callback,checkpoint,reduce_lr])

    pred_Incep = model_Incep.predict(x_test_Incep)
    
    oos_y.append(y_test_Incep)
    oos_pred.append(pred_Incep)  
    print(classification_report(y_test_Incep.argmax(axis=1),	                #แสดง report ค่า acc, recall, ...
                                        pred_Incep.argmax(axis=1),  
                                        target_names=le_Incep.classes_))
    
oos_y = np.concatenate(oos_y)
oos_pred = np.concatenate(oos_pred)
print(classification_report(oos_y.argmax(axis=1), oos_pred.argmax(axis=1),  target_names=le_Incep.classes_))

# %% [markdown]
# ### 1

# %% [markdown]
# #### 1  soft pre bi

# %%
BS = 1
filepath = "Kmodel1_soft_pre_bi.h5"                  ##

train_img_Incep = []
for ImageName in tqdm(data_train3['ImageName']):              
    image_path = All_3class_dir +'/' + ImageName                  
    img = cv2.imread(image_path)                                          
    img = cv2.resize(img, (299, 299))                                      
    train_img_Incep.append(img)
data_Incep = np.array(train_img_Incep, dtype="float32") / 255.0

labels_Incep = np.array(data_train3[['NameType']] )        
labels_Incep.shape = (len(labels_Incep),) 
le_Incep = LabelEncoder()                                                                     
labels_Incep = le_Incep.fit_transform(labels_Incep)                                         
labels_Incep = to_categorical(labels_Incep, num_classes=3)                   

aug = ImageDataGenerator( rotation_range=15,	width_shift_range=0.1, 	height_shift_range=0.1,
		shear_range=0.15, 	horizontal_flip=True, 	fill_mode="nearest")
                                                                                                           ## 
callback = EarlyStopping( monitor= "val_accuracy",    patience=15,       mode="max" , baseline=1.0)

# checkpoint = ModelCheckpoint(filepath, monitor='val_accuracy', verbose=1,   save_best_only=True, mode='max')
                                                                                                            ##
reduce_lr = ReduceLROnPlateau(monitor='val_accuracy', factor=0.5,   patience=6,     verbose=1, mode='max', min_lr=0.00001)

# %%
base_model_Incep = tf.keras.applications.InceptionV3(input_shape=(299, 299, 3), include_top=False, weights="imagenet")
len(base_model_Incep.layers)

base_model_Incep.trainable = True
for layer in base_model_Incep.layers[:100]:    #fix w & bias in layer 0-100
    layer.trainable = False


#Add custom head
average_pooling_layer = tf.keras.layers.GlobalAveragePooling2D()(base_model_Incep.output)
prediction_layer = tf.keras.layers.Dense(units=3, activation="softmax")(average_pooling_layer)   # unit 3
model_Incep = tf.keras.models.Model(inputs=base_model_Incep.input, outputs=prediction_layer)

model_Incep.compile(optimizer=RMSprop(learning_rate=0.0001), loss="binary_crossentropy", metrics=["accuracy"])


### K-fold
kf_Incep = KFold(5, shuffle=True, random_state=40) 

oos_y = []
oos_pred = []
fold = 0

for train, test in kf_Incep.split(data_Incep):
    fold+=1   
    print(f"Fold #{fold}")

    filename = f" Kmodel1_soft_pre_bi{fold}.h5 "
    checkpoint = ModelCheckpoint(filename, monitor='val_accuracy', verbose=1,   save_best_only=True, mode='max')
        
    x_train_Incep = data_Incep[train]
    y_train_Incep = labels_Incep[train]
    x_test_Incep = data_Incep[test]
    y_test_Incep = labels_Incep[test]

    H_Incep = model_Incep.fit( x=aug.flow(x_train_Incep, y_train_Incep, batch_size=BS),
	                                            validation_data=(x_test_Incep, y_test_Incep),
	                                            steps_per_epoch=len(x_train_Incep) // BS,
	                                            epochs=100,  callbacks = [callback,checkpoint,reduce_lr])

    pred_Incep = model_Incep.predict(x_test_Incep)
    
    oos_y.append(y_test_Incep)
    oos_pred.append(pred_Incep)  
    print(classification_report(y_test_Incep.argmax(axis=1),	                #แสดง report ค่า acc, recall, ...
                                        pred_Incep.argmax(axis=1),  
                                        target_names=le_Incep.classes_))
    
oos_y = np.concatenate(oos_y)
oos_pred = np.concatenate(oos_pred)
print(classification_report(oos_y.argmax(axis=1), oos_pred.argmax(axis=1),  target_names=le_Incep.classes_))

# %% [markdown]
# #### 1 soft pre bi adam

# %%
BS = 1
filepath = "Kmodel1_soft_pre_bi_adam.h5"                  ##

train_img_Incep = []
for ImageName in tqdm(data_train3['ImageName']):              
    image_path = All_3class_dir +'/' + ImageName                  
    img = cv2.imread(image_path)                                          
    img = cv2.resize(img, (299, 299))                                      
    train_img_Incep.append(img)
data_Incep = np.array(train_img_Incep, dtype="float32") / 255.0

labels_Incep = np.array(data_train3[['NameType']] )        
labels_Incep.shape = (len(labels_Incep),) 
le_Incep = LabelEncoder()                                                                     
labels_Incep = le_Incep.fit_transform(labels_Incep)                                         
labels_Incep = to_categorical(labels_Incep, num_classes=3)                   

aug = ImageDataGenerator( rotation_range=15,	width_shift_range=0.1, 	height_shift_range=0.1,
		shear_range=0.15, 	horizontal_flip=True, 	fill_mode="nearest")
                                                                                                           ## 
callback = EarlyStopping( monitor= "val_accuracy",    patience=15,       mode="max" , baseline=1.0)

# checkpoint = ModelCheckpoint(filepath, monitor='val_accuracy', verbose=1,   save_best_only=True, mode='max')
                                                                                                            ##
reduce_lr = ReduceLROnPlateau(monitor='val_accuracy', factor=0.5,   patience=6,     verbose=1, mode='max', min_lr=0.00001)

# %%
base_model_Incep = tf.keras.applications.InceptionV3(input_shape=(299, 299, 3), include_top=False, weights="imagenet")
len(base_model_Incep.layers)

base_model_Incep.trainable = True
for layer in base_model_Incep.layers[:100]:    #fix w & bias in layer 0-100
    layer.trainable = False


#Add custom head
average_pooling_layer = tf.keras.layers.GlobalAveragePooling2D()(base_model_Incep.output)
prediction_layer = tf.keras.layers.Dense(units=3, activation="softmax")(average_pooling_layer)   # unit 3
model_Incep = tf.keras.models.Model(inputs=base_model_Incep.input, outputs=prediction_layer)

model_Incep.compile(optimizer=Adam(learning_rate=0.0001), loss="binary_crossentropy", metrics=["accuracy"])


### K-fold
kf_Incep = KFold(5, shuffle=True, random_state=40) 

oos_y = []
oos_pred = []
fold = 0

for train, test in kf_Incep.split(data_Incep):
    fold+=1   
    print(f"Fold #{fold}")

    filename = f" Kmodel1_soft_pre_bi_adam{fold}.h5 "
    checkpoint = ModelCheckpoint(filename, monitor='val_accuracy', verbose=1,   save_best_only=True, mode='max')
        
    x_train_Incep = data_Incep[train]
    y_train_Incep = labels_Incep[train]
    x_test_Incep = data_Incep[test]
    y_test_Incep = labels_Incep[test]

    H_Incep = model_Incep.fit( x=aug.flow(x_train_Incep, y_train_Incep, batch_size=BS),
	                                            validation_data=(x_test_Incep, y_test_Incep),
	                                            steps_per_epoch=len(x_train_Incep) // BS,
	                                            epochs=100,  callbacks = [callback,checkpoint,reduce_lr])

    pred_Incep = model_Incep.predict(x_test_Incep)
    
    oos_y.append(y_test_Incep)
    oos_pred.append(pred_Incep)  
    print(classification_report(y_test_Incep.argmax(axis=1),	                #แสดง report ค่า acc, recall, ...
                                        pred_Incep.argmax(axis=1),  
                                        target_names=le_Incep.classes_))
    
oos_y = np.concatenate(oos_y)
oos_pred = np.concatenate(oos_pred)
print(classification_report(oos_y.argmax(axis=1), oos_pred.argmax(axis=1),  target_names=le_Incep.classes_))

# %% [markdown]
# #### 1 soft pre bi sgd

# %%
BS = 1
filepath = "Kmodel1_soft_pre_bi_sgd.h5"                  ##

train_img_Incep = []
for ImageName in tqdm(data_train3['ImageName']):              
    image_path = All_3class_dir +'/' + ImageName                  
    img = cv2.imread(image_path)                                          
    img = cv2.resize(img, (299, 299))                                      
    train_img_Incep.append(img)
data_Incep = np.array(train_img_Incep, dtype="float32") / 255.0

labels_Incep = np.array(data_train3[['NameType']] )        
labels_Incep.shape = (len(labels_Incep),) 
le_Incep = LabelEncoder()                                                                     
labels_Incep = le_Incep.fit_transform(labels_Incep)                                         
labels_Incep = to_categorical(labels_Incep, num_classes=3)                   

aug = ImageDataGenerator( rotation_range=15,	width_shift_range=0.1, 	height_shift_range=0.1,
		shear_range=0.15, 	horizontal_flip=True, 	fill_mode="nearest")
                                                                                                           ## 
callback = EarlyStopping( monitor= "val_accuracy",    patience=15,       mode="max" , baseline=1.0)

# checkpoint = ModelCheckpoint(filepath, monitor='val_accuracy', verbose=1,   save_best_only=True, mode='max')
                                                                                                            ##
reduce_lr = ReduceLROnPlateau(monitor='val_accuracy', factor=0.5,   patience=6,     verbose=1, mode='max', min_lr=0.00001)

# %%
base_model_Incep = tf.keras.applications.InceptionV3(input_shape=(299, 299, 3), include_top=False, weights="imagenet")
len(base_model_Incep.layers)

base_model_Incep.trainable = True
for layer in base_model_Incep.layers[:100]:    #fix w & bias in layer 0-100
    layer.trainable = False


#Add custom head
average_pooling_layer = tf.keras.layers.GlobalAveragePooling2D()(base_model_Incep.output)
prediction_layer = tf.keras.layers.Dense(units=3, activation="softmax")(average_pooling_layer)   # unit 3
model_Incep = tf.keras.models.Model(inputs=base_model_Incep.input, outputs=prediction_layer)

model_Incep.compile(optimizer=SGD(learning_rate=0.0001), loss="binary_crossentropy", metrics=["accuracy"])


### K-fold
kf_Incep = KFold(5, shuffle=True, random_state=40) 

oos_y = []
oos_pred = []
fold = 0

for train, test in kf_Incep.split(data_Incep):
    fold+=1   
    print(f"Fold #{fold}")

    filename = f" Kmodel1_soft_pre_bi_sgd{fold}.h5 "
    checkpoint = ModelCheckpoint(filename, monitor='val_accuracy', verbose=1,   save_best_only=True, mode='max')
        
    x_train_Incep = data_Incep[train]
    y_train_Incep = labels_Incep[train]
    x_test_Incep = data_Incep[test]
    y_test_Incep = labels_Incep[test]

    H_Incep = model_Incep.fit( x=aug.flow(x_train_Incep, y_train_Incep, batch_size=BS),
	                                            validation_data=(x_test_Incep, y_test_Incep),
	                                            steps_per_epoch=len(x_train_Incep) // BS,
	                                            epochs=100,  callbacks = [callback,checkpoint,reduce_lr])

    pred_Incep = model_Incep.predict(x_test_Incep)
    
    oos_y.append(y_test_Incep)
    oos_pred.append(pred_Incep)  
    print(classification_report(y_test_Incep.argmax(axis=1),	                #แสดง report ค่า acc, recall, ...
                                        pred_Incep.argmax(axis=1),  
                                        target_names=le_Incep.classes_))
    
oos_y = np.concatenate(oos_y)
oos_pred = np.concatenate(oos_pred)
print(classification_report(oos_y.argmax(axis=1), oos_pred.argmax(axis=1),  target_names=le_Incep.classes_))

# %% [markdown]
# #### 1 soft pre cate

# %%
BS = 1
filepath = "Kmodel1_soft_pre_cate.h5"                  ##

train_img_Incep = []
for ImageName in tqdm(data_train3['ImageName']):              
    image_path = All_3class_dir +'/' + ImageName                  
    img = cv2.imread(image_path)                                          
    img = cv2.resize(img, (299, 299))                                      
    train_img_Incep.append(img)
data_Incep = np.array(train_img_Incep, dtype="float32") / 255.0

labels_Incep = np.array(data_train3[['NameType']] )        
labels_Incep.shape = (len(labels_Incep),) 
le_Incep = LabelEncoder()                                                                     
labels_Incep = le_Incep.fit_transform(labels_Incep)                                         
labels_Incep = to_categorical(labels_Incep, num_classes=3)                   

aug = ImageDataGenerator( rotation_range=15,	width_shift_range=0.1, 	height_shift_range=0.1,
		shear_range=0.15, 	horizontal_flip=True, 	fill_mode="nearest")
                                                                                                           ## 
callback = EarlyStopping( monitor= "val_accuracy",    patience=15,       mode="max" , baseline=1.0)

# checkpoint = ModelCheckpoint(filepath, monitor='val_accuracy', verbose=1,   save_best_only=True, mode='max')
                                                                                                            ##
reduce_lr = ReduceLROnPlateau(monitor='val_accuracy', factor=0.5,   patience=6,     verbose=1, mode='max', min_lr=0.00001)

# %%
base_model_Incep = tf.keras.applications.InceptionV3(input_shape=(299, 299, 3), include_top=False, weights="imagenet")
len(base_model_Incep.layers)

base_model_Incep.trainable = True
for layer in base_model_Incep.layers[:100]:    #fix w & bias in layer 0-100
    layer.trainable = False


#Add custom head
average_pooling_layer = tf.keras.layers.GlobalAveragePooling2D()(base_model_Incep.output)
prediction_layer = tf.keras.layers.Dense(units=3, activation="softmax")(average_pooling_layer)   # unit 3
model_Incep = tf.keras.models.Model(inputs=base_model_Incep.input, outputs=prediction_layer)

model_Incep.compile(optimizer=RMSprop(learning_rate=0.0001), loss="categorical_crossentropy", metrics=["accuracy"])


### K-fold
kf_Incep = KFold(5, shuffle=True, random_state=40) 

oos_y = []
oos_pred = []
fold = 0

for train, test in kf_Incep.split(data_Incep):
    fold+=1   
    print(f"Fold #{fold}")

    filename = f" Kmodel1_soft_pre_cate{fold}.h5 "
    checkpoint = ModelCheckpoint(filename, monitor='val_accuracy', verbose=1,   save_best_only=True, mode='max')
        
    x_train_Incep = data_Incep[train]
    y_train_Incep = labels_Incep[train]
    x_test_Incep = data_Incep[test]
    y_test_Incep = labels_Incep[test]

    H_Incep = model_Incep.fit( x=aug.flow(x_train_Incep, y_train_Incep, batch_size=BS),
	                                            validation_data=(x_test_Incep, y_test_Incep),
	                                            steps_per_epoch=len(x_train_Incep) // BS,
	                                            epochs=100,  callbacks = [callback,checkpoint,reduce_lr])

    pred_Incep = model_Incep.predict(x_test_Incep)
    
    oos_y.append(y_test_Incep)
    oos_pred.append(pred_Incep)  
    print(classification_report(y_test_Incep.argmax(axis=1),	                #แสดง report ค่า acc, recall, ...
                                        pred_Incep.argmax(axis=1),  
                                        target_names=le_Incep.classes_))
    
oos_y = np.concatenate(oos_y)
oos_pred = np.concatenate(oos_pred)
print(classification_report(oos_y.argmax(axis=1), oos_pred.argmax(axis=1),  target_names=le_Incep.classes_))

# %% [markdown]
# #### 1 soft pre cate adam

# %%
BS = 1
filepath = "Kmodel1_soft_pre_cate_adam.h5"                  ##

train_img_Incep = []
for ImageName in tqdm(data_train3['ImageName']):              
    image_path = All_3class_dir +'/' + ImageName                  
    img = cv2.imread(image_path)                                          
    img = cv2.resize(img, (299, 299))                                      
    train_img_Incep.append(img)
data_Incep = np.array(train_img_Incep, dtype="float32") / 255.0

labels_Incep = np.array(data_train3[['NameType']] )        
labels_Incep.shape = (len(labels_Incep),) 
le_Incep = LabelEncoder()                                                                     
labels_Incep = le_Incep.fit_transform(labels_Incep)                                         
labels_Incep = to_categorical(labels_Incep, num_classes=3)                   

aug = ImageDataGenerator( rotation_range=15,	width_shift_range=0.1, 	height_shift_range=0.1,
		shear_range=0.15, 	horizontal_flip=True, 	fill_mode="nearest")
                                                                                                           ## 
callback = EarlyStopping( monitor= "val_accuracy",    patience=15,       mode="max" , baseline=1.0)

# checkpoint = ModelCheckpoint(filepath, monitor='val_accuracy', verbose=1,   save_best_only=True, mode='max')
                                                                                                            ##
reduce_lr = ReduceLROnPlateau(monitor='val_accuracy', factor=0.5,   patience=6,     verbose=1, mode='max', min_lr=0.00001)

# %%
base_model_Incep = tf.keras.applications.InceptionV3(input_shape=(299, 299, 3), include_top=False, weights="imagenet")
len(base_model_Incep.layers)

base_model_Incep.trainable = True
for layer in base_model_Incep.layers[:100]:    #fix w & bias in layer 0-100
    layer.trainable = False


#Add custom head
average_pooling_layer = tf.keras.layers.GlobalAveragePooling2D()(base_model_Incep.output)
prediction_layer = tf.keras.layers.Dense(units=3, activation="softmax")(average_pooling_layer)   # unit 3
model_Incep = tf.keras.models.Model(inputs=base_model_Incep.input, outputs=prediction_layer)

model_Incep.compile(optimizer=Adam(learning_rate=0.0001), loss="categorical_crossentropy", metrics=["accuracy"])

### K-fold
kf_Incep = KFold(5, shuffle=True, random_state=40) 

oos_y = []
oos_pred = []
fold = 0

for train, test in kf_Incep.split(data_Incep):
    fold+=1   
    print(f"Fold #{fold}")

    filename = f" Kmodel1_soft_pre_cate_adam{fold}.h5 "
    checkpoint = ModelCheckpoint(filename, monitor='val_accuracy', verbose=1,   save_best_only=True, mode='max')
        
    x_train_Incep = data_Incep[train]
    y_train_Incep = labels_Incep[train]
    x_test_Incep = data_Incep[test]
    y_test_Incep = labels_Incep[test]

    H_Incep = model_Incep.fit( x=aug.flow(x_train_Incep, y_train_Incep, batch_size=BS),
	                                            validation_data=(x_test_Incep, y_test_Incep),
	                                            steps_per_epoch=len(x_train_Incep) // BS,
	                                            epochs=100,  callbacks = [callback,checkpoint,reduce_lr])

    pred_Incep = model_Incep.predict(x_test_Incep)
    
    oos_y.append(y_test_Incep)
    oos_pred.append(pred_Incep)  
    print(classification_report(y_test_Incep.argmax(axis=1),	                #แสดง report ค่า acc, recall, ...
                                        pred_Incep.argmax(axis=1),  
                                        target_names=le_Incep.classes_))
    
oos_y = np.concatenate(oos_y)
oos_pred = np.concatenate(oos_pred)
print(classification_report(oos_y.argmax(axis=1), oos_pred.argmax(axis=1),  target_names=le_Incep.classes_))

# %% [markdown]
# #### 1 soft pre cate sgd

# %%
BS = 1
filepath = "Kmodel1_soft_pre_cate_sgd.h5"                  ##

train_img_Incep = []
for ImageName in tqdm(data_train3['ImageName']):              
    image_path = All_3class_dir +'/' + ImageName                  
    img = cv2.imread(image_path)                                          
    img = cv2.resize(img, (299, 299))                                      
    train_img_Incep.append(img)
data_Incep = np.array(train_img_Incep, dtype="float32") / 255.0

labels_Incep = np.array(data_train3[['NameType']] )        
labels_Incep.shape = (len(labels_Incep),) 
le_Incep = LabelEncoder()                                                                     
labels_Incep = le_Incep.fit_transform(labels_Incep)                                         
labels_Incep = to_categorical(labels_Incep, num_classes=3)                   

aug = ImageDataGenerator( rotation_range=15,	width_shift_range=0.1, 	height_shift_range=0.1,
		shear_range=0.15, 	horizontal_flip=True, 	fill_mode="nearest")
                                                                                                           ## 
callback = EarlyStopping( monitor= "val_accuracy",    patience=15,       mode="max" , baseline=1.0)

# checkpoint = ModelCheckpoint(filepath, monitor='val_accuracy', verbose=1,   save_best_only=True, mode='max')
                                                                                                            ##
reduce_lr = ReduceLROnPlateau(monitor='val_accuracy', factor=0.5,   patience=6,     verbose=1, mode='max', min_lr=0.00001)

# %%
base_model_Incep = tf.keras.applications.InceptionV3(input_shape=(299, 299, 3), include_top=False, weights="imagenet")
len(base_model_Incep.layers)

base_model_Incep.trainable = True
for layer in base_model_Incep.layers[:100]:    #fix w & bias in layer 0-100
    layer.trainable = False


#Add custom head
average_pooling_layer = tf.keras.layers.GlobalAveragePooling2D()(base_model_Incep.output)
prediction_layer = tf.keras.layers.Dense(units=3, activation="softmax")(average_pooling_layer)   # unit 3
model_Incep = tf.keras.models.Model(inputs=base_model_Incep.input, outputs=prediction_layer)

model_Incep.compile(optimizer=SGD(learning_rate=0.0001), loss="categorical_crossentropy", metrics=["accuracy"])

### K-fold
kf_Incep = KFold(5, shuffle=True, random_state=40) 

oos_y = []
oos_pred = []
fold = 0

for train, test in kf_Incep.split(data_Incep):
    fold+=1   
    print(f"Fold #{fold}")

    filename = f" Kmodel1_soft_pre_cate_sgd{fold}.h5 "
    checkpoint = ModelCheckpoint(filename, monitor='val_accuracy', verbose=1,   save_best_only=True, mode='max')
        
    x_train_Incep = data_Incep[train]
    y_train_Incep = labels_Incep[train]
    x_test_Incep = data_Incep[test]
    y_test_Incep = labels_Incep[test]

    H_Incep = model_Incep.fit( x=aug.flow(x_train_Incep, y_train_Incep, batch_size=BS),
	                                            validation_data=(x_test_Incep, y_test_Incep),
	                                            steps_per_epoch=len(x_train_Incep) // BS,
	                                            epochs=100,  callbacks = [callback,checkpoint,reduce_lr])

    pred_Incep = model_Incep.predict(x_test_Incep)
    
    oos_y.append(y_test_Incep)
    oos_pred.append(pred_Incep)  
    print(classification_report(y_test_Incep.argmax(axis=1),	                #แสดง report ค่า acc, recall, ...
                                        pred_Incep.argmax(axis=1),  
                                        target_names=le_Incep.classes_))
    
oos_y = np.concatenate(oos_y)
oos_pred = np.concatenate(oos_pred)
print(classification_report(oos_y.argmax(axis=1), oos_pred.argmax(axis=1),  target_names=le_Incep.classes_))
